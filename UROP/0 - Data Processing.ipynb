# %%
import sys
sys.path.insert(0, "..")

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# # Data Processing
# In this notebook, we will be processing the data in the ACM Dataset.
#
# The first step is to understand the information we want to extract from our dataset.

# %%
PATH="../data/ACM Data/"

# %%
from utils.xml import Proceeding2DataFrame

with open(f'{PATH}PROC--1967-2402536.xml', 'rb') as f:
    data = f.read()
    xml2df = Proceeding2DataFrame(data)
    df = xml2df.process()

# %%
df
# Out:
#    article_id                                           fulltext  \
# 0     2402563  The Development of Systems for On-Line Mathema...
# 1     2402565  An Analysis of Computer Operations Under Runni...
# 2     2402566  AMessage System for Interactive Dialog G. C. P...
# 3     2402567  AMacroscopic Model of an Interactive Computing...
# 4     2402568  A Content-Evaluating Mode of Computer-Aided In...
# 5     2402569  OLDAS: An On-Line Continuous System Simulation...
# 6     2402571  On the Construction of Polyalgorithms for Auto...
# 7     2402572  A Proposed Numerical Accuracy Control System H...
# 8     2402573  A Learning Program for the Integration of Syst...
# 9     2402574  On Experiences with PIL, an Interpretive Langu...
# 10    2402575  Curve Fitting and Editing via Interactive Grap...
# 11    2402576  FORTRAN Codes to Fit Curves Interactively LYLE...
# 12    2402577  Analyst Assistance Program (AAP) ANNE B. AMMER...
# ...

# %%
df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-ad11118bc8f3> in <module>()
# ----> 1 df[0]
#
# ...
