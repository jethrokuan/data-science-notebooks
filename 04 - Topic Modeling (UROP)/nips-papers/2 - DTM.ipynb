# %% [markdown]
# # Initial Setup

# %%
import sys
sys.path.insert(0, "../..")

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
PATH="/diskA/jethro/nips-papers"

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
from utils.timeit import timeit

# %%
import pandas as pd

# %% [markdown]
# # Loading the Dictionary and Corpus

# %%
from gensim.corpora import Dictionary
from gensim.corpora.mmcorpus import MmCorpus
# Out:
# 2018-03-11 14:28:30,220 : INFO : 'pattern' package not found; tag filters are not available for English

# %%
dct = Dictionary.load(f'{PATH}/dictionary.pkl')
# Out:
# 2018-03-11 14:28:30,249 : INFO : loading Dictionary object from /diskA/jethro/nips-papers/dictionary.pkl
# 2018-03-11 14:28:30,273 : INFO : loaded /diskA/jethro/nips-papers/dictionary.pkl

# %%
corpus = MmCorpus(f'{PATH}/corpus.mm')
# Out:
# 2018-03-11 14:28:30,485 : INFO : loaded corpus index from /diskA/jethro/nips-papers/corpus.mm.index
# 2018-03-11 14:28:30,485 : INFO : initializing corpus reader from /diskA/jethro/nips-papers/corpus.mm
# 2018-03-11 14:28:30,486 : INFO : accepted corpus with 7241 documents, 54254 features, 2350382 non-zero entries

# %%
import pickle
with open(f'{PATH}/timeseq.lst', 'rb') as f:
    time_seq = pickle.load(f)

# %%
from subprocess import call
import os.path

if not os.path.isfile("dtm-linux64"):
    call(["wget", "https://github.com/magsilva/dtm/raw/master/bin/dtm-linux64"])
    call(["chmod", "+x", "dtm-linux64"])

# %%
DTM_EXECUTABLE = "./dtm-linux64"

# %% [markdown]
# # Training the Model

# %%
from gensim.models.wrappers import DtmModel

# %%
NUM_TOPICS = 30

# %%
@timeit
def train_model(corpus, dct):
    return DtmModel(DTM_EXECUTABLE, corpus, id2word=dct, time_slices=time_seq, num_topics=NUM_TOPICS)

# %%
dtm = train_model(corpus, dct)
# Out:
# 2018-03-10 22:00:09,485 : INFO : serializing temporary corpus to /tmp/70040e_train-mult.dat
# 2018-03-10 22:00:09,485 : INFO : no word id mapping provided; initializing from corpus
# 2018-03-10 22:00:12,935 : INFO : storing corpus in Blei's LDA-C format into /tmp/70040e_train-mult.dat
# 2018-03-10 22:00:16,735 : INFO : saving vocabulary of 54254 words to /tmp/70040e_train-mult.dat.vocab
# 2018-03-10 22:00:16,778 : INFO : training DTM with args --ntopics=30 --model=dtm  --mode=fit --initialize_lda=true --corpus_prefix=/tmp/70040e_train --outname=/tmp/70040e_train_out --alpha=0.01 --lda_max_em_iter=10 --lda_sequence_min_iter=6  --lda_sequence_max_iter=20 --top_chain_var=0.005 --rng_seed=0
# 2018-03-10 22:00:16,778 : INFO : Running command ['./dtm-linux64', '--ntopics=30', '--model=dtm', '--mode=fit', '--initialize_lda=true', '--corpus_prefix=/tmp/70040e_train', '--outname=/tmp/70040e_train_out', '--alpha=0.01', '--lda_max_em_iter=10', '--lda_sequence_min_iter=6', '--lda_sequence_max_iter=20', '--top_chain_var=0.005', '--rng_seed=0']
# 2018-03-11 01:54:13,855 : INFO : 'train_model'  14044371.88 ms

# %%
dtm.save(f'{PATH}/dtm.gensim')
# Out:
# 2018-03-11 01:54:13,873 : INFO : saving DtmModel object under /diskA/jethro/nips-papers/dtm.gensim, separately None
# 2018-03-11 01:54:13,873 : INFO : storing np array 'lambda_' to /diskA/jethro/nips-papers/dtm.gensim.lambda_.npy
# 2018-03-11 01:54:14,707 : INFO : storing np array 'obs_' to /diskA/jethro/nips-papers/dtm.gensim.obs_.npy
# 2018-03-11 01:54:15,566 : INFO : saved /diskA/jethro/nips-papers/dtm.gensim

# %% [markdown]
# # Visualizing the Results

# %%
NUM_TIMES=3

# %%
dtm = DtmModel.load(f'{PATH}/dtm.gensim')
# Out:
# 2018-03-11 14:28:42,676 : INFO : loading DtmModel object from /diskA/jethro/nips-papers/dtm.gensim
# 2018-03-11 14:28:43,972 : INFO : loading id2word recursively from /diskA/jethro/nips-papers/dtm.gensim.id2word.* with mmap=None
# 2018-03-11 14:28:43,972 : INFO : loading lambda_ from /diskA/jethro/nips-papers/dtm.gensim.lambda_.npy with mmap=None
# 2018-03-11 14:28:55,289 : INFO : loading obs_ from /diskA/jethro/nips-papers/dtm.gensim.obs_.npy with mmap=None
# 2018-03-11 14:29:02,193 : INFO : loaded /diskA/jethro/nips-papers/dtm.gensim

# %%
topics = dtm.show_topics(formatted=False, num_words=6, num_topics=-1, times=NUM_TIMES)
# Out:
# /home/jethro/anaconda3/envs/urop/lib/python3.6/site-packages/gensim/models/wrappers/dtmmodel.py:294: UserWarning: The parameter `num_words` is deprecated, will be removed in 4.0.0, use `topn` instead.
#   warnings.warn("The parameter `num_words` is deprecated, will be removed in 4.0.0, use `topn` instead.")

# %%
from utils.array import chunks

# %%
def slice_to_dict(slce):
    d = dict()
    for topic_id, words in enumerate(slce):
        d[f'topic_{topic_id}'] = [word for rank, (prob, word) in enumerate(words)]
    return d

# %%
slice0, slice1, slice2 = chunks(topics, 30)

# %%
pd.DataFrame(slice_to_dict(slice0)).transpose()
# Out:
#                     0               1            2             3  \
# topic_0          node            tree        graph       message
# topic_1      operator             rbf       kernel    regression
# topic_10         rule          symbol      grammar        string
# topic_11        curve      expression   eigenvalue  eigenvectors
# topic_12   classifier  classification      pattern      decision
# topic_13       speech     recognition       signal          word
# topic_14       region           group        gamma       mixture
# topic_15         code  transformation     rotation   translation
# topic_16       neuron          memory      circuit          chip
# topic_17   prediction            risk         loss     predictor
# topic_18         cell          neuron     response      activity
# topic_19   validation         support        plane        margin
# topic_2      capacity           bound   complexity       theorem
# topic_20  equilibrium        strategy         game      position
# topic_21     distance         cluster       center     prototype
# topic_22        phase             arm      learner        online
# topic_23     equation     convergence     gradient  optimization
# topic_24         unit           layer      pattern    activation
# topic_25     sequence         control   controller         chain
# topic_26       action   reinforcement      control   environment
# topic_27       energy           field  temperature    transition
# topic_28         user           query    retrieval      document
# topic_29    character            word       letter          role
# topic_3         image          object        pixel   recognition
# topic_4    projection           basis    selection       product
# topic_5           map           motor       target           eye
# topic_6        motion       direction     velocity         field
# topic_7     component         density      mixture     dimension
# topic_8      transfer          expert      episode           rnn
# topic_9         noise        estimate     variance    estimation
#
#                         4             5
# topic_0              path          link
# topic_1            spline       product
# topic_10   generalization    population
# topic_11             gene       patient
# topic_12            label          tree
# topic_13          speaker       phoneme
# topic_14            event     component
# topic_15            digit    invariance
# topic_16           analog    connection
# topic_17     minimization    hypothesis
# topic_18          pattern      stimulus
# topic_19       hyperplane         cross
# topic_2             proof    hypothesis
# topic_20             move         board
# topic_21         neighbor    assignment
# topic_22         strategy        bandit
# topic_23       constraint       minimum
# topic_24  backpropagation  architecture
# topic_25          protein         plant
# topic_26       controller          goal
# topic_27        boltzmann          spin
# topic_28             word          text
# topic_29      recognition      language
# topic_3           surface        vision
# topic_4           pursuit    regression
# topic_5             brain      response
# topic_6        trajectory         robot
# topic_7         principle       mapping
# topic_8           decoder   translation
# topic_9        likelihood     criterion

# %%
pd.DataFrame(slice_to_dict(slice1)).transpose()
# Out:
#                     0               1            2             3  \
# topic_0          node            tree        graph       message
# topic_1      operator             rbf       kernel    regression
# topic_10         rule          symbol      grammar        string
# topic_11        curve      expression   eigenvalue  eigenvectors
# topic_12   classifier  classification      pattern      decision
# topic_13       speech     recognition       signal          word
# topic_14       region           group        gamma       mixture
# topic_15         code  transformation     rotation   translation
# topic_16       neuron          memory      circuit          chip
# topic_17   prediction            risk         loss     predictor
# topic_18         cell          neuron     response      activity
# topic_19   validation         support        plane        margin
# topic_2      capacity           bound   complexity       theorem
# topic_20  equilibrium        strategy         game      position
# topic_21     distance         cluster       center     prototype
# topic_22        phase             arm      learner        online
# topic_23     equation     convergence     gradient  optimization
# topic_24         unit           layer      pattern    activation
# topic_25     sequence         control   controller         chain
# topic_26       action   reinforcement      control   environment
# topic_27       energy           field  temperature    transition
# topic_28         user           query    retrieval      document
# topic_29         word       character       letter   recognition
# topic_3         image          object        pixel   recognition
# topic_4    projection           basis    selection       product
# topic_5           map          target        motor           eye
# topic_6        motion       direction     velocity         field
# topic_7     component         density      mixture     dimension
# topic_8      transfer          expert      episode           rnn
# topic_9         noise        estimate     variance    estimation
#
#                         4             5
# topic_0              path          edge
# topic_1            spline       product
# topic_10   generalization    population
# topic_11             gene       patient
# topic_12            label          tree
# topic_13          speaker       phoneme
# topic_14            event     component
# topic_15            digit    invariance
# topic_16           analog       voltage
# topic_17     minimization    hypothesis
# topic_18          pattern      stimulus
# topic_19       hyperplane         cross
# topic_2             proof       concept
# topic_20             move         board
# topic_21         neighbor       measure
# topic_22         strategy        bandit
# topic_23       constraint       descent
# topic_24  backpropagation  architecture
# topic_25          protein         plant
# topic_26       controller          goal
# topic_27        boltzmann          spin
# topic_28             word          text
# topic_29             role      language
# topic_3           surface        vision
# topic_4           pursuit    regression
# topic_5          response      movement
# topic_6        trajectory         robot
# topic_7         principle       mapping
# topic_8           decoder   translation
# topic_9        likelihood     criterion

# %%
pd.DataFrame(slice_to_dict(slice2)).transpose()
# Out:
#                     0               1            2             3  \
# topic_0          node            tree        graph          path
# topic_1      operator             rbf       kernel    regression
# topic_10         rule          symbol      grammar        string
# topic_11        curve      expression   eigenvalue  eigenvectors
# topic_12   classifier  classification      pattern      decision
# topic_13       speech     recognition       signal          word
# topic_14       region           group        gamma       mixture
# topic_15         code  transformation     rotation         digit
# topic_16       memory          neuron      circuit          chip
# topic_17   prediction            risk         loss     predictor
# topic_18         cell          neuron     response      activity
# topic_19   validation         support        plane        margin
# topic_2         bound      complexity     capacity       theorem
# topic_20  equilibrium        strategy         game      position
# topic_21     distance         cluster       center     prototype
# topic_22        phase             arm      learner        online
# topic_23     equation     convergence     gradient  optimization
# topic_24         unit           layer      pattern  architecture
# topic_25      control        sequence   controller         chain
# topic_26       action   reinforcement      control   environment
# topic_27        field          energy  temperature    transition
# topic_28        query            user    retrieval      document
# topic_29         word       character       letter   recognition
# topic_3         image          object  recognition         pixel
# topic_4    projection           basis    selection       product
# topic_5           map          target          eye         motor
# topic_6        motion       direction     velocity    trajectory
# topic_7     component         density      mixture     dimension
# topic_8        expert        transfer      episode           rnn
# topic_9         noise        estimate     variance    estimation
#
#                         4            5
# topic_0           message         edge
# topic_1            spline      product
# topic_10   generalization    knowledge
# topic_11             gene      patient
# topic_12            label     accuracy
# topic_13          speaker      phoneme
# topic_14            event    component
# topic_15      translation   invariance
# topic_16           analog      voltage
# topic_17     minimization   hypothesis
# topic_18          pattern     stimulus
# topic_19       hyperplane        cross
# topic_2             proof      concept
# topic_20             move        board
# topic_21         neighbor      measure
# topic_22         strategy       bandit
# topic_23       constraint      descent
# topic_24  backpropagation   activation
# topic_25          protein        plant
# topic_26       controller         goal
# topic_27        boltzmann       markov
# topic_28             word         text
# topic_29         language         role
# topic_3            vision      surface
# topic_4           pursuit   regression
# topic_5          movement     response
# topic_6             field        robot
# topic_7         principle      mapping
# topic_8           decoder  translation
# topic_9        likelihood    criterion

# %%
d = dict()
for idx, chunk in enumerate(chunks(topics, NUM_TOPICS)):
    for topic_id, words in enumerate(chunk):
        d[f'topic_{topic_id}_slice_{idx}'] = [word for rank, (prob, word) in enumerate(words)]

# %%
pd.DataFrame(d).transpose()[:30]
# Out:
#                            0               1           2             3  \
# topic_0_slice_0         node            tree       graph       message
# topic_0_slice_1         node            tree       graph       message
# topic_0_slice_2         node            tree       graph          path
# topic_10_slice_0        rule          symbol     grammar        string
# topic_10_slice_1        rule          symbol     grammar        string
# topic_10_slice_2        rule          symbol     grammar        string
# topic_11_slice_0       curve      expression  eigenvalue  eigenvectors
# topic_11_slice_1       curve      expression  eigenvalue  eigenvectors
# topic_11_slice_2       curve      expression  eigenvalue  eigenvectors
# topic_12_slice_0  classifier  classification     pattern      decision
# topic_12_slice_1  classifier  classification     pattern      decision
# topic_12_slice_2  classifier  classification     pattern      decision
# topic_13_slice_0      speech     recognition      signal          word
# topic_13_slice_1      speech     recognition      signal          word
# topic_13_slice_2      speech     recognition      signal          word
# topic_14_slice_0      region           group       gamma       mixture
# topic_14_slice_1      region           group       gamma       mixture
# topic_14_slice_2      region           group       gamma       mixture
# topic_15_slice_0        code  transformation    rotation   translation
# topic_15_slice_1        code  transformation    rotation   translation
# topic_15_slice_2        code  transformation    rotation         digit
# topic_16_slice_0      neuron          memory     circuit          chip
# topic_16_slice_1      neuron          memory     circuit          chip
# topic_16_slice_2      memory          neuron     circuit          chip
# topic_17_slice_0  prediction            risk        loss     predictor
# topic_17_slice_1  prediction            risk        loss     predictor
# topic_17_slice_2  prediction            risk        loss     predictor
# topic_18_slice_0        cell          neuron    response      activity
# topic_18_slice_1        cell          neuron    response      activity
# topic_18_slice_2        cell          neuron    response      activity
#
#                                4           5
# topic_0_slice_0             path        link
# topic_0_slice_1             path        edge
# topic_0_slice_2          message        edge
# topic_10_slice_0  generalization  population
# topic_10_slice_1  generalization  population
# topic_10_slice_2  generalization   knowledge
# topic_11_slice_0            gene     patient
# topic_11_slice_1            gene     patient
# topic_11_slice_2            gene     patient
# topic_12_slice_0           label        tree
# topic_12_slice_1           label        tree
# topic_12_slice_2           label    accuracy
# topic_13_slice_0         speaker     phoneme
# topic_13_slice_1         speaker     phoneme
# topic_13_slice_2         speaker     phoneme
# topic_14_slice_0           event   component
# topic_14_slice_1           event   component
# topic_14_slice_2           event   component
# topic_15_slice_0           digit  invariance
# topic_15_slice_1           digit  invariance
# topic_15_slice_2     translation  invariance
# topic_16_slice_0          analog  connection
# topic_16_slice_1          analog     voltage
# topic_16_slice_2          analog     voltage
# topic_17_slice_0    minimization  hypothesis
# topic_17_slice_1    minimization  hypothesis
# topic_17_slice_2    minimization  hypothesis
# topic_18_slice_0         pattern    stimulus
# topic_18_slice_1         pattern    stimulus
# topic_18_slice_2         pattern    stimulus

# %%
topics = dtm.show_topics(formatted=False, num_words=10, num_topics=1, times=10)
# Out:
# /home/jethro/anaconda3/envs/urop/lib/python3.6/site-packages/gensim/models/wrappers/dtmmodel.py:294: UserWarning: The parameter `num_words` is deprecated, will be removed in 4.0.0, use `topn` instead.
#   warnings.warn("The parameter `num_words` is deprecated, will be removed in 4.0.0, use `topn` instead.")

# %%
d = dict()
for idx, chunk in enumerate(chunks(topics, 10)):
    for slice_id, words in enumerate(chunk):
        d[f'slice_{slice_id}'] = [word for rank, (prob, word) in enumerate(words)]
pd.DataFrame(d).transpose()
# Out:
#             0     1      2        3        4        5        6            7  \
# slice_0  node  tree  graph  message     path     link     edge        cycle
# slice_1  node  tree  graph  message     path     edge     link        cycle
# slice_2  node  tree  graph     path  message     edge     link        cycle
# slice_3  node  tree  graph     path  message     edge     link        cycle
# slice_4  node  tree  graph     path     edge  message     link       parent
# slice_5  node  tree  graph     path     edge  message     link       parent
# slice_6  node  tree  graph     path     edge  message     link       parent
# slice_7  node  tree  graph     path     edge  message     link       parent
# slice_8  node  tree  graph     path     edge  message   parent  propagation
# slice_9  node  tree  graph     path     edge   belief  message  propagation
#
#               8            9
# slice_0  branch       parent
# slice_1  branch       parent
# slice_2  branch       parent
# slice_3  parent       branch
# slice_4   cycle        level
# slice_5   level         leaf
# slice_6    leaf        level
# slice_7    leaf  propagation
# slice_8  belief         link
# slice_9  parent         leaf
