# %% [markdown]
# # Inititial Setup

# %%
import sys
sys.path.insert(0, "../..")

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
PATH="/diskA/jethro/nips-papers"

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
import pandas as pd

# %%
from utils.timeit import timeit

# %% [markdown]
# # Loading Dictionary and Corpus

# %%
from gensim.corpora import Dictionary
from gensim.corpora.mmcorpus import MmCorpus
# Out:
# 2018-03-10 16:52:14,192 : INFO : 'pattern' package not found; tag filters are not available for English

# %%
dct = Dictionary.load(f'{PATH}/dictionary.pkl')
# Out:
# 2018-03-10 16:52:14,210 : INFO : loading Dictionary object from /diskA/jethro/nips-papers/dictionary.pkl
# 2018-03-10 16:52:14,226 : INFO : loaded /diskA/jethro/nips-papers/dictionary.pkl

# %%
corpus = MmCorpus(f'{PATH}/corpus.mm')
# Out:
# 2018-03-10 16:52:14,239 : INFO : loaded corpus index from /diskA/jethro/nips-papers/corpus.mm.index
# 2018-03-10 16:52:14,240 : INFO : initializing corpus reader from /diskA/jethro/nips-papers/corpus.mm
# 2018-03-10 16:52:14,241 : INFO : accepted corpus with 7241 documents, 54254 features, 2350382 non-zero entries

# %% [markdown]
# # Training the Model

# %%
NUM_TOPICS=30

# %%
CHUNKSIZE=500

# %%
NUM_ITERATIONS=200

# %%
from gensim.models.ldamodel import LdaModel

# %%
@timeit
def train_model(corpus, dct):
    return LdaModel(corpus, id2word=dct, num_topics=NUM_TOPICS, chunksize=CHUNKSIZE, iterations=NUM_ITERATIONS, alpha='auto')

# %%
lda = train_model(corpus, dct)
# Out:
# 2018-03-10 16:52:14,313 : INFO : using autotuned alpha, starting with [0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335]
# 2018-03-10 16:52:14,313 : INFO : using symmetric eta at 0.03333333333333333
# 2018-03-10 16:52:14,318 : INFO : using serial LDA version on this node
# 2018-03-10 16:52:29,160 : INFO : running online (single-pass) LDA training, 30 topics, 1 passes over the supplied corpus of 7241 documents, updating model once every 500 documents, evaluating perplexity every 5000 documents, iterating 200x with a convergence threshold of 0.001000
# 2018-03-10 16:52:29,322 : INFO : PROGRESS: pass 0, at document #500/7241
# 2018-03-10 16:52:34,015 : INFO : optimized alpha [0.02759488, 0.03580175, 0.03443912, 0.03170344, 0.033324074, 0.028087597, 0.030340403, 0.028144874, 0.028670311, 0.02815571, 0.032311376, 0.033004634, 0.02796535, 0.028048256, 0.028102867, 0.035674863, 0.028619237, 0.02800624, 0.028053878, 0.032177493, 0.027666789, 0.027530013, 0.028845757, 0.031970512, 0.030422447, 0.02912921, 0.031234404, 0.028297167, 0.030809237, 0.02830915]
# 2018-03-10 16:52:34,030 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 16:52:34,566 : INFO : topic #0 (0.028): 0.013*"connection" + 0.012*"circuit" + 0.012*"change" + 0.010*"equation" + 0.010*"lattice" + 0.009*"neuron" + 0.009*"controller" + 0.009*"concept" + 0.009*"constraint" + 0.008*"inhibition"
# 2018-03-10 16:52:34,567 : INFO : topic #21 (0.028): 0.019*"cell" + 0.016*"fiber" + 0.012*"neuron" + 0.011*"cortex" + 0.011*"region" + 0.010*"projection" + 0.008*"response" + 0.008*"pattern" + 0.007*"receptor" + 0.007*"organization"
# 2018-03-10 16:52:34,569 : INFO : topic #2 (0.034): 0.036*"unit" + 0.013*"image" + 0.013*"pattern" + 0.010*"recognition" + 0.009*"layer" + 0.009*"word" + 0.008*"sequence" + 0.007*"memory" + 0.006*"equation" + 0.006*"character"
# 2018-03-10 16:52:34,570 : INFO : topic #15 (0.036): 0.022*"unit" + 0.018*"cell" + 0.015*"recognition" + 0.014*"speech" + 0.012*"neuron" + 0.010*"pattern" + 0.009*"layer" + 0.009*"connection" + 0.009*"activation" + 0.006*"word"
# 2018-03-10 16:52:34,571 : INFO : topic #1 (0.036): 0.013*"unit" + 0.011*"pattern" + 0.011*"neuron" + 0.009*"control" + 0.008*"response" + 0.007*"cell" + 0.006*"velocity" + 0.005*"equation" + 0.005*"field" + 0.005*"image"
# 2018-03-10 16:52:34,573 : INFO : topic diff=27.693241, rho=1.000000
# 2018-03-10 16:52:34,739 : INFO : PROGRESS: pass 0, at document #1000/7241
# 2018-03-10 16:52:36,660 : INFO : optimized alpha [0.030342204, 0.045283593, 0.047031727, 0.040051, 0.041030798, 0.031800848, 0.036233205, 0.0303727, 0.030125896, 0.032624565, 0.037513614, 0.04011255, 0.031234916, 0.033110008, 0.03127131, 0.04444717, 0.03352348, 0.031542365, 0.033626903, 0.03847924, 0.032494836, 0.029955206, 0.031817313, 0.03671651, 0.03731988, 0.031135684, 0.035876673, 0.030931693, 0.03847742, 0.029930005]
# 2018-03-10 16:52:36,675 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 16:52:37,821 : INFO : topic #29 (0.030): 0.021*"classifier" + 0.018*"rbf" + 0.018*"trajectory" + 0.017*"hand" + 0.010*"movement" + 0.010*"mixture" + 0.010*"neuron" + 0.008*"control" + 0.008*"classification" + 0.008*"force"
# 2018-03-10 16:52:37,822 : INFO : topic #21 (0.030): 0.028*"cell" + 0.016*"cortex" + 0.013*"neuron" + 0.013*"projection" + 0.013*"activity" + 0.012*"rat" + 0.011*"movement" + 0.010*"phase" + 0.010*"response" + 0.009*"correlation"
# 2018-03-10 16:52:37,823 : INFO : topic #15 (0.044): 0.019*"recognition" + 0.019*"speech" + 0.019*"unit" + 0.014*"word" + 0.013*"cell" + 0.010*"neuron" + 0.010*"layer" + 0.008*"pattern" + 0.008*"connection" + 0.007*"activation"
# 2018-03-10 16:52:37,824 : INFO : topic #1 (0.045): 0.012*"control" + 0.010*"unit" + 0.009*"pattern" + 0.009*"neuron" + 0.008*"velocity" + 0.007*"response" + 0.006*"gain" + 0.006*"cell" + 0.006*"field" + 0.006*"line"
# 2018-03-10 16:52:37,825 : INFO : topic #2 (0.047): 0.033*"unit" + 0.015*"image" + 0.013*"word" + 0.013*"recognition" + 0.012*"sequence" + 0.011*"pattern" + 0.011*"layer" + 0.008*"recurrent" + 0.007*"character" + 0.007*"object"
# 2018-03-10 16:52:37,827 : INFO : topic diff=2.420414, rho=0.707107
# 2018-03-10 16:52:37,999 : INFO : PROGRESS: pass 0, at document #1500/7241
# 2018-03-10 16:52:39,661 : INFO : optimized alpha [0.03469647, 0.057470918, 0.059098795, 0.052664854, 0.04861997, 0.034373283, 0.04316053, 0.034019288, 0.034521602, 0.038880527, 0.045012437, 0.04866544, 0.03613545, 0.0401991, 0.034826703, 0.05228432, 0.041437164, 0.03476543, 0.039541032, 0.045518838, 0.03999881, 0.032619115, 0.03430624, 0.04210032, 0.045821555, 0.034140248, 0.04317492, 0.033553846, 0.047898553, 0.031442404]
# 2018-03-10 16:52:39,676 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 16:52:40,929 : INFO : topic #29 (0.031): 0.025*"hand" + 0.023*"classifier" + 0.022*"rbf" + 0.018*"trajectory" + 0.014*"song" + 0.013*"movement" + 0.010*"control" + 0.008*"mixture" + 0.008*"field" + 0.008*"force"
# 2018-03-10 16:52:40,930 : INFO : topic #21 (0.033): 0.038*"cell" + 0.019*"cortex" + 0.015*"activity" + 0.014*"movement" + 0.014*"rat" + 0.012*"correlation" + 0.012*"direction" + 0.011*"phase" + 0.011*"neuron" + 0.011*"stimulus"
# 2018-03-10 16:52:40,931 : INFO : topic #3 (0.053): 0.013*"loss" + 0.011*"noise" + 0.011*"prediction" + 0.010*"regression" + 0.010*"estimate" + 0.008*"entropy" + 0.008*"validation" + 0.007*"density" + 0.006*"spike" + 0.006*"classification"
# 2018-03-10 16:52:40,933 : INFO : topic #1 (0.057): 0.011*"control" + 0.009*"velocity" + 0.008*"unit" + 0.008*"response" + 0.008*"frequency" + 0.007*"stimulus" + 0.007*"motion" + 0.007*"pattern" + 0.006*"neuron" + 0.006*"line"
# 2018-03-10 16:52:40,934 : INFO : topic #2 (0.059): 0.028*"unit" + 0.017*"image" + 0.017*"recognition" + 0.016*"word" + 0.014*"sequence" + 0.011*"face" + 0.010*"pattern" + 0.009*"layer" + 0.008*"recurrent" + 0.007*"character"
# 2018-03-10 16:52:40,936 : INFO : topic diff=2.071033, rho=0.577350
# 2018-03-10 16:52:41,116 : INFO : PROGRESS: pass 0, at document #2000/7241
# 2018-03-10 16:52:42,724 : INFO : optimized alpha [0.039609887, 0.07077839, 0.07373371, 0.069598444, 0.056240555, 0.038050465, 0.050623775, 0.039034992, 0.03983927, 0.046379574, 0.052267797, 0.057874244, 0.043746404, 0.048012152, 0.038639218, 0.06076596, 0.051144157, 0.038924545, 0.047563426, 0.05437217, 0.049074546, 0.035143044, 0.037200153, 0.047142055, 0.054771006, 0.03776123, 0.05143578, 0.03585886, 0.059527084, 0.03319515]
# 2018-03-10 16:52:42,739 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 16:52:43,909 : INFO : topic #29 (0.033): 0.025*"classifier" + 0.023*"song" + 0.023*"hand" + 0.017*"rbf" + 0.016*"movement" + 0.015*"trajectory" + 0.010*"force" + 0.009*"control" + 0.009*"muscle" + 0.008*"behavior"
# 2018-03-10 16:52:43,911 : INFO : topic #21 (0.035): 0.045*"cell" + 0.018*"activity" + 0.018*"cortex" + 0.016*"correlation" + 0.015*"movement" + 0.014*"direction" + 0.014*"response" + 0.013*"stimulus" + 0.013*"oscillator" + 0.011*"phase"
# 2018-03-10 16:52:43,912 : INFO : topic #3 (0.070): 0.013*"loss" + 0.013*"noise" + 0.013*"kernel" + 0.012*"regression" + 0.010*"density" + 0.010*"estimate" + 0.009*"entropy" + 0.009*"prediction" + 0.007*"instance" + 0.007*"estimation"
# 2018-03-10 16:52:43,913 : INFO : topic #1 (0.071): 0.011*"control" + 0.009*"frequency" + 0.009*"stimulus" + 0.009*"response" + 0.008*"velocity" + 0.007*"gain" + 0.006*"pattern" + 0.006*"unit" + 0.006*"line" + 0.006*"filter"
# 2018-03-10 16:52:43,914 : INFO : topic #2 (0.074): 0.022*"unit" + 0.019*"image" + 0.018*"word" + 0.017*"recognition" + 0.017*"sequence" + 0.013*"face" + 0.008*"pattern" + 0.007*"layer" + 0.007*"context" + 0.007*"recurrent"
# 2018-03-10 16:52:43,916 : INFO : topic diff=1.849729, rho=0.500000
# 2018-03-10 16:52:44,117 : INFO : PROGRESS: pass 0, at document #2500/7241
# 2018-03-10 16:52:45,675 : INFO : optimized alpha [0.044905566, 0.08553924, 0.09135184, 0.09071698, 0.0661294, 0.04204913, 0.059834644, 0.044549417, 0.04581663, 0.05561235, 0.05988475, 0.06765454, 0.053640977, 0.05649349, 0.042605095, 0.06867078, 0.06384508, 0.043120407, 0.05898657, 0.06535056, 0.059977114, 0.038276605, 0.0403281, 0.052294526, 0.06414938, 0.040948085, 0.060597364, 0.03888659, 0.075141005, 0.03608083]
# 2018-03-10 16:52:45,691 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 16:52:46,815 : INFO : topic #29 (0.036): 0.028*"trajectory" + 0.024*"movement" + 0.022*"classifier" + 0.022*"hand" + 0.018*"song" + 0.013*"body" + 0.012*"control" + 0.011*"tube" + 0.011*"classification" + 0.010*"rbf"
# 2018-03-10 16:52:46,816 : INFO : topic #21 (0.038): 0.046*"cell" + 0.019*"activity" + 0.019*"cortex" + 0.016*"correlation" + 0.015*"movement" + 0.015*"stimulus" + 0.014*"response" + 0.013*"phase" + 0.013*"direction" + 0.011*"population"
# 2018-03-10 16:52:46,817 : INFO : topic #1 (0.086): 0.010*"control" + 0.009*"frequency" + 0.008*"response" + 0.008*"stimulus" + 0.007*"filter" + 0.006*"velocity" + 0.006*"gain" + 0.006*"line" + 0.006*"effect" + 0.005*"signal"
# 2018-03-10 16:52:46,818 : INFO : topic #3 (0.091): 0.021*"kernel" + 0.020*"loss" + 0.013*"regression" + 0.013*"noise" + 0.011*"estimate" + 0.011*"prediction" + 0.009*"density" + 0.008*"instance" + 0.008*"entropy" + 0.007*"estimation"
# 2018-03-10 16:52:46,820 : INFO : topic #2 (0.091): 0.025*"word" + 0.020*"sequence" + 0.017*"image" + 0.015*"unit" + 0.015*"recognition" + 0.013*"face" + 0.008*"object" + 0.008*"pattern" + 0.007*"sentence" + 0.007*"context"
# 2018-03-10 16:52:46,821 : INFO : topic diff=1.816750, rho=0.447214
# 2018-03-10 16:52:47,037 : INFO : PROGRESS: pass 0, at document #3000/7241
# 2018-03-10 16:52:48,536 : INFO : optimized alpha [0.051171094, 0.10205249, 0.11159152, 0.11530697, 0.07790918, 0.04639079, 0.07189022, 0.050902955, 0.052496135, 0.06645222, 0.06953312, 0.07730786, 0.06508645, 0.066866115, 0.047439583, 0.078366145, 0.077757396, 0.04921267, 0.07279057, 0.07807091, 0.07297744, 0.04257415, 0.04411286, 0.05743074, 0.07606524, 0.044333577, 0.072096705, 0.043013588, 0.09258745, 0.03944278]
# 2018-03-10 16:52:48,552 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 16:52:49,626 : INFO : topic #29 (0.039): 0.030*"hand" + 0.027*"movement" + 0.027*"trajectory" + 0.016*"classifier" + 0.014*"arm" + 0.014*"motor" + 0.014*"song" + 0.013*"body" + 0.010*"classification" + 0.010*"csp"
# 2018-03-10 16:52:49,627 : INFO : topic #21 (0.043): 0.038*"cell" + 0.022*"activity" + 0.019*"cortex" + 0.018*"movement" + 0.016*"correlation" + 0.015*"stimulus" + 0.015*"response" + 0.014*"population" + 0.013*"phase" + 0.012*"brain"
# 2018-03-10 16:52:49,628 : INFO : topic #1 (0.102): 0.008*"stimulus" + 0.008*"control" + 0.008*"response" + 0.008*"frequency" + 0.008*"gain" + 0.007*"filter" + 0.006*"effect" + 0.006*"line" + 0.006*"music" + 0.006*"signal"
# 2018-03-10 16:52:49,630 : INFO : topic #2 (0.112): 0.032*"word" + 0.023*"sequence" + 0.016*"image" + 0.014*"recognition" + 0.012*"face" + 0.011*"unit" + 0.009*"object" + 0.007*"pattern" + 0.007*"context" + 0.007*"sentence"
# 2018-03-10 16:52:49,631 : INFO : topic #3 (0.115): 0.022*"kernel" + 0.021*"loss" + 0.015*"regression" + 0.013*"prediction" + 0.012*"estimate" + 0.012*"noise" + 0.010*"density" + 0.010*"instance" + 0.008*"estimation" + 0.008*"entropy"
# 2018-03-10 16:52:49,633 : INFO : topic diff=1.683414, rho=0.408248
# 2018-03-10 16:52:49,875 : INFO : PROGRESS: pass 0, at document #3500/7241
# 2018-03-10 16:52:51,326 : INFO : optimized alpha [0.058534678, 0.121282674, 0.13163742, 0.14706416, 0.089050986, 0.052281514, 0.08381716, 0.059231825, 0.06110406, 0.07952585, 0.078239396, 0.08799328, 0.07871529, 0.07940573, 0.052001067, 0.088579305, 0.096190155, 0.056495145, 0.08938584, 0.09235242, 0.090161234, 0.046563387, 0.04890787, 0.061473064, 0.09009157, 0.048589736, 0.085603796, 0.048223965, 0.113929264, 0.043554615]
# 2018-03-10 16:52:51,342 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 16:52:52,396 : INFO : topic #29 (0.044): 0.029*"hand" + 0.028*"movement" + 0.028*"trajectory" + 0.021*"arm" + 0.019*"motor" + 0.016*"bci" + 0.015*"control" + 0.013*"trial" + 0.013*"subject" + 0.012*"csp"
# 2018-03-10 16:52:52,397 : INFO : topic #21 (0.047): 0.034*"cell" + 0.024*"activity" + 0.020*"cortex" + 0.019*"stimulus" + 0.017*"brain" + 0.017*"response" + 0.015*"phase" + 0.015*"movement" + 0.015*"population" + 0.014*"correlation"
# 2018-03-10 16:52:52,398 : INFO : topic #1 (0.121): 0.010*"control" + 0.009*"gain" + 0.009*"response" + 0.009*"stimulus" + 0.008*"effect" + 0.008*"filter" + 0.008*"frequency" + 0.007*"line" + 0.007*"trial" + 0.006*"crf"
# 2018-03-10 16:52:52,399 : INFO : topic #2 (0.132): 0.040*"word" + 0.022*"sequence" + 0.015*"image" + 0.013*"recognition" + 0.011*"face" + 0.009*"context" + 0.009*"unit" + 0.009*"object" + 0.007*"category" + 0.007*"sentence"
# 2018-03-10 16:52:52,401 : INFO : topic #3 (0.147): 0.022*"loss" + 0.020*"kernel" + 0.018*"regression" + 0.014*"prediction" + 0.013*"estimate" + 0.011*"noise" + 0.011*"instance" + 0.010*"estimator" + 0.009*"density" + 0.009*"estimation"
# 2018-03-10 16:52:52,403 : INFO : topic diff=1.584826, rho=0.377964
# 2018-03-10 16:52:52,666 : INFO : PROGRESS: pass 0, at document #4000/7241
# 2018-03-10 16:52:54,058 : INFO : optimized alpha [0.06695833, 0.14063378, 0.15654497, 0.18448733, 0.10197337, 0.05970642, 0.100043915, 0.0701557, 0.07199509, 0.09331585, 0.09012993, 0.09941951, 0.09559469, 0.09457181, 0.0572258, 0.10030608, 0.11757753, 0.0648416, 0.107502334, 0.1096998, 0.11276211, 0.05067108, 0.05325825, 0.06565209, 0.10411289, 0.053091086, 0.10298935, 0.055584267, 0.1423525, 0.0482258]
# 2018-03-10 16:52:54,073 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 16:52:55,098 : INFO : topic #29 (0.048): 0.034*"trajectory" + 0.033*"movement" + 0.032*"arm" + 0.029*"hand" + 0.021*"motor" + 0.018*"control" + 0.014*"trial" + 0.014*"subject" + 0.013*"bci" + 0.011*"body"
# 2018-03-10 16:52:55,099 : INFO : topic #21 (0.051): 0.031*"cell" + 0.028*"brain" + 0.026*"activity" + 0.021*"cortex" + 0.020*"stimulus" + 0.019*"population" + 0.018*"response" + 0.017*"correlation" + 0.016*"phase" + 0.013*"movement"
# 2018-03-10 16:52:55,101 : INFO : topic #28 (0.142): 0.031*"optimization" + 0.017*"margin" + 0.016*"norm" + 0.016*"label" + 0.014*"constraint" + 0.013*"convex" + 0.013*"gradient" + 0.013*"risk" + 0.011*"cost" + 0.010*"sparsity"
# 2018-03-10 16:52:55,102 : INFO : topic #2 (0.157): 0.046*"word" + 0.021*"sequence" + 0.014*"image" + 0.013*"recognition" + 0.011*"object" + 0.011*"context" + 0.011*"category" + 0.009*"face" + 0.009*"sentence" + 0.008*"unit"
# 2018-03-10 16:52:55,103 : INFO : topic #3 (0.184): 0.029*"loss" + 0.021*"regression" + 0.017*"kernel" + 0.013*"prediction" + 0.012*"estimate" + 0.012*"noise" + 0.012*"instance" + 0.012*"estimator" + 0.010*"estimation" + 0.009*"log"
# 2018-03-10 16:52:55,105 : INFO : topic diff=1.478086, rho=0.353553
# 2018-03-10 16:52:55,372 : INFO : PROGRESS: pass 0, at document #4500/7241
# 2018-03-10 16:52:56,757 : INFO : optimized alpha [0.07587691, 0.16384494, 0.17922775, 0.22738492, 0.1159421, 0.068088725, 0.118480995, 0.08176549, 0.083290614, 0.10905328, 0.10319171, 0.11229095, 0.11453387, 0.112211816, 0.062337555, 0.11224015, 0.14119577, 0.072673984, 0.13089325, 0.12707902, 0.13783078, 0.054959316, 0.05902449, 0.070933, 0.11827469, 0.057734177, 0.12172282, 0.063104324, 0.17567143, 0.0534302]
# 2018-03-10 16:52:56,772 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 16:52:57,753 : INFO : topic #29 (0.053): 0.047*"arm" + 0.034*"movement" + 0.031*"trajectory" + 0.030*"hand" + 0.019*"motor" + 0.015*"control" + 0.014*"trial" + 0.013*"subject" + 0.011*"bci" + 0.011*"body"
# 2018-03-10 16:52:57,755 : INFO : topic #21 (0.055): 0.034*"cell" + 0.033*"brain" + 0.025*"activity" + 0.023*"population" + 0.022*"cortex" + 0.021*"correlation" + 0.019*"stimulus" + 0.018*"response" + 0.013*"phase" + 0.012*"trial"
# 2018-03-10 16:52:57,756 : INFO : topic #28 (0.176): 0.034*"optimization" + 0.018*"norm" + 0.015*"convex" + 0.015*"margin" + 0.014*"label" + 0.014*"constraint" + 0.013*"gradient" + 0.012*"risk" + 0.011*"cost" + 0.010*"sparsity"
# 2018-03-10 16:52:57,757 : INFO : topic #2 (0.179): 0.043*"word" + 0.019*"sequence" + 0.014*"recognition" + 0.014*"category" + 0.013*"image" + 0.013*"context" + 0.011*"object" + 0.008*"sentence" + 0.008*"face" + 0.008*"unit"
# 2018-03-10 16:52:57,758 : INFO : topic #3 (0.227): 0.031*"loss" + 0.022*"regression" + 0.015*"prediction" + 0.014*"kernel" + 0.013*"noise" + 0.012*"estimate" + 0.012*"estimator" + 0.012*"instance" + 0.012*"estimation" + 0.010*"log"
# 2018-03-10 16:52:57,760 : INFO : topic diff=1.227916, rho=0.333333
# 2018-03-10 16:53:02,131 : INFO : -8.553 per-word bound, 375.7 perplexity estimate based on a held-out corpus of 500 documents with 412100 words
# 2018-03-10 16:53:02,131 : INFO : PROGRESS: pass 0, at document #5000/7241
# 2018-03-10 16:53:03,464 : INFO : optimized alpha [0.08665882, 0.18936786, 0.20543651, 0.27527374, 0.12788697, 0.07880094, 0.13888432, 0.09489703, 0.09503568, 0.12470128, 0.117582366, 0.12524372, 0.13756928, 0.13477422, 0.06684921, 0.12400881, 0.16468103, 0.08221097, 0.15679589, 0.14537883, 0.16793299, 0.059467614, 0.065359, 0.0757835, 0.13418877, 0.062252436, 0.14507191, 0.07139338, 0.21262753, 0.058838278]
# 2018-03-10 16:53:03,488 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 16:53:04,447 : INFO : topic #29 (0.059): 0.059*"arm" + 0.036*"trajectory" + 0.031*"movement" + 0.027*"hand" + 0.018*"motor" + 0.016*"song" + 0.014*"subject" + 0.014*"control" + 0.014*"trial" + 0.013*"bci"
# 2018-03-10 16:53:04,448 : INFO : topic #21 (0.059): 0.035*"cell" + 0.032*"brain" + 0.027*"activity" + 0.023*"population" + 0.021*"cortex" + 0.021*"correlation" + 0.018*"response" + 0.018*"stimulus" + 0.014*"phase" + 0.013*"trial"
# 2018-03-10 16:53:04,449 : INFO : topic #2 (0.205): 0.045*"word" + 0.017*"sequence" + 0.014*"recognition" + 0.013*"category" + 0.012*"image" + 0.012*"context" + 0.010*"object" + 0.008*"layer" + 0.007*"unit" + 0.007*"sentence"
# 2018-03-10 16:53:04,450 : INFO : topic #28 (0.213): 0.038*"optimization" + 0.020*"norm" + 0.016*"convex" + 0.015*"gradient" + 0.013*"constraint" + 0.013*"label" + 0.012*"risk" + 0.011*"loss" + 0.011*"margin" + 0.011*"cost"
# 2018-03-10 16:53:04,451 : INFO : topic #3 (0.275): 0.032*"loss" + 0.021*"regression" + 0.017*"estimator" + 0.014*"prediction" + 0.013*"estimation" + 0.013*"noise" + 0.012*"kernel" + 0.012*"estimate" + 0.010*"instance" + 0.010*"log"
# 2018-03-10 16:53:04,453 : INFO : topic diff=1.052292, rho=0.316228
# 2018-03-10 16:53:04,727 : INFO : PROGRESS: pass 0, at document #5500/7241
# 2018-03-10 16:53:06,088 : INFO : optimized alpha [0.09865956, 0.21677777, 0.23319677, 0.32675162, 0.14195876, 0.090593286, 0.15717848, 0.108713165, 0.1066427, 0.14247806, 0.13424331, 0.13816373, 0.16190809, 0.15817574, 0.07299756, 0.13422965, 0.19035384, 0.09057853, 0.18741667, 0.16600288, 0.20100783, 0.06407575, 0.07206277, 0.08175372, 0.15104322, 0.06754768, 0.17036329, 0.08064117, 0.25626883, 0.06463879]
# 2018-03-10 16:53:06,103 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 16:53:06,989 : INFO : topic #21 (0.064): 0.036*"cell" + 0.033*"brain" + 0.028*"activity" + 0.024*"population" + 0.019*"correlation" + 0.019*"cortex" + 0.018*"stimulus" + 0.017*"response" + 0.013*"phase" + 0.012*"trial"
# 2018-03-10 16:53:06,991 : INFO : topic #29 (0.065): 0.079*"arm" + 0.047*"trajectory" + 0.028*"movement" + 0.023*"hand" + 0.018*"control" + 0.017*"feedback" + 0.017*"song" + 0.015*"motor" + 0.013*"trial" + 0.012*"subject"
# 2018-03-10 16:53:06,992 : INFO : topic #2 (0.233): 0.048*"word" + 0.014*"sequence" + 0.013*"recognition" + 0.013*"category" + 0.012*"context" + 0.011*"image" + 0.009*"layer" + 0.009*"sentence" + 0.009*"object" + 0.006*"unit"
# 2018-03-10 16:53:06,993 : INFO : topic #28 (0.256): 0.038*"optimization" + 0.021*"norm" + 0.017*"convex" + 0.015*"gradient" + 0.013*"loss" + 0.013*"label" + 0.013*"constraint" + 0.012*"cost" + 0.011*"margin" + 0.011*"risk"
# 2018-03-10 16:53:06,994 : INFO : topic #3 (0.327): 0.034*"loss" + 0.020*"regression" + 0.020*"estimator" + 0.014*"prediction" + 0.014*"estimation" + 0.013*"estimate" + 0.013*"noise" + 0.011*"kernel" + 0.010*"log" + 0.010*"instance"
# 2018-03-10 16:53:06,996 : INFO : topic diff=0.908149, rho=0.301511
# 2018-03-10 16:53:07,281 : INFO : PROGRESS: pass 0, at document #6000/7241
# 2018-03-10 16:53:08,730 : INFO : optimized alpha [0.11276366, 0.24664354, 0.25900823, 0.38428608, 0.1533238, 0.10386356, 0.18063402, 0.1224836, 0.12032017, 0.15834431, 0.15367483, 0.14963025, 0.18927664, 0.18461427, 0.07765743, 0.14805493, 0.21611764, 0.10056451, 0.22069664, 0.18649551, 0.2374337, 0.068679534, 0.080268376, 0.0881861, 0.16730532, 0.07245818, 0.19725098, 0.09217086, 0.30739334, 0.07097188]
# 2018-03-10 16:53:08,745 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 16:53:09,595 : INFO : topic #21 (0.069): 0.039*"brain" + 0.035*"cell" + 0.029*"population" + 0.027*"activity" + 0.019*"response" + 0.018*"correlation" + 0.017*"stimulus" + 0.016*"cortex" + 0.013*"trial" + 0.013*"phase"
# 2018-03-10 16:53:09,596 : INFO : topic #29 (0.071): 0.091*"arm" + 0.051*"trajectory" + 0.024*"control" + 0.024*"movement" + 0.020*"hand" + 0.019*"feedback" + 0.018*"song" + 0.012*"motor" + 0.011*"trial" + 0.010*"kim"
# 2018-03-10 16:53:09,597 : INFO : topic #2 (0.259): 0.044*"word" + 0.016*"sequence" + 0.012*"recognition" + 0.012*"layer" + 0.012*"sentence" + 0.011*"context" + 0.011*"image" + 0.010*"category" + 0.009*"worker" + 0.007*"object"
# 2018-03-10 16:53:09,598 : INFO : topic #28 (0.307): 0.042*"optimization" + 0.021*"norm" + 0.018*"gradient" + 0.017*"convex" + 0.013*"loss" + 0.013*"constraint" + 0.013*"descent" + 0.012*"risk" + 0.011*"convergence" + 0.011*"label"
# 2018-03-10 16:53:09,599 : INFO : topic #3 (0.384): 0.033*"loss" + 0.022*"estimator" + 0.021*"regression" + 0.015*"estimation" + 0.015*"prediction" + 0.013*"estimate" + 0.012*"noise" + 0.011*"log" + 0.010*"kernel" + 0.010*"instance"
# 2018-03-10 16:53:09,601 : INFO : topic diff=0.817545, rho=0.288675
# 2018-03-10 16:53:09,891 : INFO : PROGRESS: pass 0, at document #6500/7241
# 2018-03-10 16:53:11,358 : INFO : optimized alpha [0.12902395, 0.27931613, 0.2907521, 0.4452994, 0.16933429, 0.1195561, 0.2008041, 0.13598795, 0.1365726, 0.17280573, 0.17680217, 0.16358596, 0.21714626, 0.21184203, 0.084687226, 0.16495858, 0.24441618, 0.11069771, 0.25212598, 0.21195374, 0.27513832, 0.07324768, 0.08994046, 0.09536193, 0.18453595, 0.07709526, 0.2269217, 0.10396521, 0.36470428, 0.0776145]
# 2018-03-10 16:53:11,373 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 16:53:12,177 : INFO : topic #21 (0.073): 0.040*"brain" + 0.032*"cell" + 0.030*"population" + 0.025*"activity" + 0.019*"response" + 0.017*"correlation" + 0.016*"stimulus" + 0.015*"cortex" + 0.015*"trial" + 0.012*"phase"
# 2018-03-10 16:53:12,178 : INFO : topic #25 (0.077): 0.099*"document" + 0.033*"price" + 0.029*"market" + 0.011*"customer" + 0.010*"coreset" + 0.009*"day" + 0.008*"consensus" + 0.008*"bregman" + 0.008*"response" + 0.007*"localization"
# 2018-03-10 16:53:12,180 : INFO : topic #2 (0.291): 0.040*"word" + 0.015*"layer" + 0.015*"sequence" + 0.013*"recognition" + 0.011*"worker" + 0.011*"image" + 0.010*"category" + 0.010*"sentence" + 0.010*"context" + 0.007*"architecture"
# 2018-03-10 16:53:12,181 : INFO : topic #28 (0.365): 0.045*"optimization" + 0.020*"gradient" + 0.019*"norm" + 0.017*"convex" + 0.015*"loss" + 0.013*"constraint" + 0.013*"descent" + 0.012*"convergence" + 0.011*"risk" + 0.010*"cost"
# 2018-03-10 16:53:12,182 : INFO : topic #3 (0.445): 0.036*"loss" + 0.024*"estimator" + 0.020*"regression" + 0.016*"estimation" + 0.014*"prediction" + 0.013*"estimate" + 0.012*"noise" + 0.011*"log" + 0.009*"divergence" + 0.009*"kernel"
# 2018-03-10 16:53:12,184 : INFO : topic diff=0.713174, rho=0.277350
# 2018-03-10 16:53:12,506 : INFO : PROGRESS: pass 0, at document #7000/7241
# 2018-03-10 16:53:14,033 : INFO : optimized alpha [0.14664324, 0.31624424, 0.3298367, 0.51173913, 0.18584043, 0.13862701, 0.22240247, 0.15042582, 0.15425321, 0.19062026, 0.2037394, 0.18383354, 0.24878633, 0.24281724, 0.09475918, 0.18562761, 0.27495676, 0.12087625, 0.2873902, 0.23967329, 0.31462106, 0.07983833, 0.1018274, 0.10335849, 0.20697899, 0.08180128, 0.2607793, 0.1167174, 0.42222366, 0.08770652]
# 2018-03-10 16:53:14,058 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 16:53:14,851 : INFO : topic #21 (0.080): 0.042*"brain" + 0.031*"cell" + 0.027*"population" + 0.025*"activity" + 0.019*"response" + 0.016*"correlation" + 0.015*"cortex" + 0.015*"stimulus" + 0.014*"trial" + 0.011*"reaction"
# 2018-03-10 16:53:14,852 : INFO : topic #25 (0.082): 0.082*"document" + 0.043*"price" + 0.034*"market" + 0.011*"coreset" + 0.011*"consensus" + 0.010*"day" + 0.010*"bregman" + 0.009*"trader" + 0.008*"customer" + 0.007*"trade"
# 2018-03-10 16:53:14,854 : INFO : topic #2 (0.330): 0.034*"word" + 0.016*"layer" + 0.015*"sequence" + 0.013*"recognition" + 0.011*"worker" + 0.011*"image" + 0.010*"sentence" + 0.010*"context" + 0.008*"category" + 0.008*"architecture"
# 2018-03-10 16:53:14,855 : INFO : topic #28 (0.422): 0.046*"optimization" + 0.022*"gradient" + 0.018*"norm" + 0.017*"convex" + 0.016*"loss" + 0.014*"descent" + 0.013*"constraint" + 0.012*"convergence" + 0.011*"risk" + 0.010*"cost"
# 2018-03-10 16:53:14,856 : INFO : topic #3 (0.512): 0.040*"loss" + 0.024*"estimator" + 0.021*"regression" + 0.016*"estimation" + 0.014*"prediction" + 0.013*"noise" + 0.013*"estimate" + 0.011*"log" + 0.010*"divergence" + 0.009*"density"
# 2018-03-10 16:53:14,857 : INFO : topic diff=0.609913, rho=0.267261
# 2018-03-10 16:53:17,956 : INFO : -8.372 per-word bound, 331.2 perplexity estimate based on a held-out corpus of 241 documents with 232076 words
# 2018-03-10 16:53:17,956 : INFO : PROGRESS: pass 0, at document #7241/7241
# 2018-03-10 16:53:18,723 : INFO : optimized alpha [0.16616637, 0.35699028, 0.36643854, 0.5808852, 0.20086814, 0.16136728, 0.24266718, 0.1656908, 0.1719931, 0.20933059, 0.23062761, 0.20636868, 0.2811464, 0.27563715, 0.105057314, 0.20698324, 0.3058717, 0.13309707, 0.32827392, 0.2635119, 0.35750192, 0.0872831, 0.11385829, 0.110205635, 0.227564, 0.08669711, 0.29251933, 0.13299277, 0.48284, 0.097390115]
# 2018-03-10 16:53:18,748 : INFO : merging changes from 241 documents into a model of 7241 documents
# 2018-03-10 16:53:19,507 : INFO : topic #25 (0.087): 0.072*"document" + 0.042*"price" + 0.030*"market" + 0.013*"consensus" + 0.010*"bregman" + 0.010*"day" + 0.010*"coreset" + 0.008*"reserve" + 0.008*"customer" + 0.008*"trader"
# 2018-03-10 16:53:19,508 : INFO : topic #21 (0.087): 0.046*"brain" + 0.035*"cell" + 0.032*"population" + 0.023*"correlation" + 0.022*"activity" + 0.016*"response" + 0.013*"stimulus" + 0.012*"region" + 0.012*"trial" + 0.012*"study"
# 2018-03-10 16:53:19,509 : INFO : topic #2 (0.366): 0.032*"word" + 0.015*"layer" + 0.014*"sequence" + 0.012*"recognition" + 0.010*"image" + 0.010*"context" + 0.010*"sentence" + 0.009*"architecture" + 0.009*"translation" + 0.009*"language"
# 2018-03-10 16:53:19,510 : INFO : topic #28 (0.483): 0.047*"optimization" + 0.023*"gradient" + 0.019*"norm" + 0.017*"loss" + 0.017*"convex" + 0.016*"descent" + 0.012*"convergence" + 0.012*"constraint" + 0.011*"cost" + 0.011*"risk"
# 2018-03-10 16:53:19,511 : INFO : topic #3 (0.581): 0.040*"loss" + 0.026*"estimator" + 0.020*"regression" + 0.017*"estimation" + 0.014*"prediction" + 0.013*"noise" + 0.012*"estimate" + 0.012*"log" + 0.012*"divergence" + 0.009*"density"
# 2018-03-10 16:53:19,513 : INFO : topic diff=0.494360, rho=0.258199
# 2018-03-10 16:53:19,517 : INFO : 'train_model'  65205.39 ms

# %% [markdown]
# # Visualizing the Results

# %%
topics = lda.show_topics(formatted=False, num_words=6, num_topics=NUM_TOPICS)
d = dict()
for topic_id, words in topics:
    d[f'topic_{topic_id}'] = [word for rank, (word, prob) in enumerate(words)]

# %%
pd.DataFrame(d).transpose()
# Out:
#                        0             1               2              3  \
# topic_0           online         batch             rnn        learner
# topic_1           effect    adaptation            gain        control
# topic_10          oracle      preprint          memory            cnn
# topic_11          policy        action          reward           game
# topic_12       inference         arxiv          source         markov
# topic_13        gradient   convergence       iteration         policy
# topic_14           image        filter           patch          video
# topic_15           arxiv         event         dropout         speech
# topic_16  classification      datasets      classifier         kernel
# topic_17           topic          rule           round        program
# topic_18         theorem         bound         cluster          lemma
# topic_19           image      distance        subspace        dataset
# topic_2             word         layer        sequence    recognition
# topic_20           bound           log  regularization       variance
# topic_21           brain          cell      population    correlation
# topic_22            gene        design           power           cnns
# topic_23          neuron         spike        response       activity
# topic_24            edge  segmentation           image         target
# topic_25        document         price          market      consensus
# topic_26          kernel    projection        recovery       operator
# topic_27            node       message        language  communication
# topic_28    optimization      gradient            norm           loss
# topic_29             arm    trajectory        feedback        control
# topic_3             loss     estimator      regression     estimation
# topic_4            image           map          object      detection
# topic_5            layer        latent            code           user
# topic_6            graph        tensor          vertex           edge
# topic_7            group  optimization      constraint      iteration
# topic_8             cvpr     influence          rating           relu
# topic_9          mixture    covariance      likelihood      component
#
#                         4              5
# topic_0        eigenvalue      stability
# topic_1              line       response
# topic_10            phase       capacity
# topic_11            agent         regret
# topic_12            chain  factorization
# topic_13           update       equation
# topic_14            pixel          scene
# topic_15         sequence    recognition
# topic_16            query           tree
# topic_17             word           atom
# topic_18       complexity          proof
# topic_19        component           face
# topic_2             image        context
# topic_20  hyperparameters     complexity
# topic_21         activity       response
# topic_22          circuit    calibration
# topic_23         stimulus     population
# topic_24            label          field
# topic_25          bregman            day
# topic_26       embeddings         column
# topic_27          runtime         parent
# topic_28           convex        descent
# topic_29             song       movement
# topic_3        prediction          noise
# topic_4         attention         motion
# topic_5      architecture           unit
# topic_6     decomposition        ranking
# topic_7         marginals         solver
# topic_8            effect     prediction
# topic_9           density     estimation
