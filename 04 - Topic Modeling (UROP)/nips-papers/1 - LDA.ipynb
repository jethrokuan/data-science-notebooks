# %% [markdown]
# # Inititial Setup

# %%
import sys
sys.path.insert(0, "../..")

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
PATH="/diskA/jethro/nips-papers"

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
import pandas as pd

# %%
from utils.timeit import timeit

# %% [markdown]
# # Loading Dictionary and Corpus

# %%
from gensim.corpora import Dictionary
from gensim.corpora.mmcorpus import MmCorpus

# %%
dct = Dictionary.load(f'{PATH}/dictionary.pkl')
# Out:
# 2018-03-10 21:53:05,706 : INFO : loading Dictionary object from /diskA/jethro/nips-papers/dictionary.pkl
# 2018-03-10 21:53:05,719 : INFO : loaded /diskA/jethro/nips-papers/dictionary.pkl

# %%
corpus = MmCorpus(f'{PATH}/corpus.mm')
# Out:
# 2018-03-10 21:53:05,768 : INFO : loaded corpus index from /diskA/jethro/nips-papers/corpus.mm.index
# 2018-03-10 21:53:05,769 : INFO : initializing corpus reader from /diskA/jethro/nips-papers/corpus.mm
# 2018-03-10 21:53:05,770 : INFO : accepted corpus with 7241 documents, 54254 features, 2350382 non-zero entries

# %% [markdown]
# # Training the Model

# %%
NUM_TOPICS=30

# %%
NUM_PASSES=200

# %%
CHUNKSIZE=1500

# %%
NUM_ITERATIONS=200

# %%
from gensim.models.ldamodel import LdaModel

# %%
@timeit
def train_model(corpus, dct):
    return LdaModel(corpus, id2word=dct, num_topics=NUM_TOPICS, chunksize=CHUNKSIZE, iterations=NUM_ITERATIONS, alpha='auto')

# %%
lda = train_model(corpus, dct)
# Out:
# 2018-03-10 21:53:07,168 : INFO : using autotuned alpha, starting with [0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335]
# 2018-03-10 21:53:07,169 : INFO : using symmetric eta at 0.03333333333333333
# 2018-03-10 21:53:07,179 : INFO : using serial LDA version on this node
# 2018-03-10 21:53:21,665 : INFO : running online (single-pass) LDA training, 30 topics, 1 passes over the supplied corpus of 7241 documents, updating model once every 500 documents, evaluating perplexity every 5000 documents, iterating 200x with a convergence threshold of 0.001000
# 2018-03-10 21:53:21,846 : INFO : PROGRESS: pass 0, at document #500/7241
# 2018-03-10 21:53:24,904 : INFO : optimized alpha [0.027836934, 0.033907436, 0.027831443, 0.032123134, 0.031907458, 0.02808403, 0.029705364, 0.032394033, 0.03233901, 0.027056955, 0.026543006, 0.027221022, 0.03576778, 0.029076157, 0.03183942, 0.030495211, 0.03513321, 0.029771738, 0.03190823, 0.028827809, 0.029231451, 0.029905185, 0.030687556, 0.028409041, 0.028207514, 0.028221853, 0.02667699, 0.028727613, 0.030233584, 0.032231994]
# 2018-03-10 21:53:24,919 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 21:53:25,437 : INFO : topic #10 (0.027): 0.026*"node" + 0.015*"activation" + 0.010*"equivalence" + 0.009*"signature" + 0.009*"pattern" + 0.009*"concept" + 0.008*"binding" + 0.008*"attractor" + 0.006*"bound" + 0.006*"plane"
# 2018-03-10 21:53:25,438 : INFO : topic #26 (0.027): 0.025*"connection" + 0.025*"unit" + 0.018*"width" + 0.017*"delay" + 0.016*"rule" + 0.015*"timedelays" + 0.013*"window" + 0.009*"lattice" + 0.009*"neuron" + 0.008*"tempo"
# 2018-03-10 21:53:25,439 : INFO : topic #1 (0.034): 0.050*"unit" + 0.014*"image" + 0.014*"layer" + 0.009*"pattern" + 0.007*"activation" + 0.006*"rule" + 0.006*"connection" + 0.006*"backpropagation" + 0.005*"equation" + 0.005*"field"
# 2018-03-10 21:53:25,440 : INFO : topic #16 (0.035): 0.025*"unit" + 0.013*"pattern" + 0.010*"classifier" + 0.008*"neuron" + 0.007*"activation" + 0.007*"connection" + 0.007*"layer" + 0.006*"energy" + 0.006*"recognition" + 0.006*"letter"
# 2018-03-10 21:53:25,441 : INFO : topic #12 (0.036): 0.033*"unit" + 0.011*"memory" + 0.010*"neuron" + 0.010*"equation" + 0.007*"pattern" + 0.006*"backpropagation" + 0.006*"activation" + 0.006*"response" + 0.005*"generalization" + 0.005*"gradient"
# 2018-03-10 21:53:25,443 : INFO : topic diff=27.704704, rho=1.000000
# 2018-03-10 21:53:25,606 : INFO : PROGRESS: pass 0, at document #1000/7241
# 2018-03-10 21:53:27,521 : INFO : optimized alpha [0.034638144, 0.04514554, 0.032556903, 0.038612824, 0.038672067, 0.029694783, 0.0354911, 0.03971002, 0.041177146, 0.029609453, 0.03054169, 0.030493235, 0.048297964, 0.031786665, 0.036537018, 0.03712544, 0.042130683, 0.033997122, 0.037688643, 0.032233033, 0.03433158, 0.033810124, 0.034251634, 0.033032537, 0.033959582, 0.03093343, 0.032603197, 0.03058588, 0.033743516, 0.037221476]
# 2018-03-10 21:53:27,535 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 21:53:28,609 : INFO : topic #9 (0.030): 0.036*"rule" + 0.020*"transition" + 0.011*"saliency" + 0.011*"oscillation" + 0.009*"phase" + 0.008*"delay" + 0.007*"activation" + 0.007*"line" + 0.007*"cun" + 0.007*"synchronization"
# 2018-03-10 21:53:28,610 : INFO : topic #5 (0.030): 0.018*"block" + 0.016*"chip" + 0.012*"layer" + 0.010*"bit" + 0.010*"building" + 0.009*"neuron" + 0.008*"board" + 0.008*"control" + 0.008*"net" + 0.008*"signal"
# 2018-03-10 21:53:28,611 : INFO : topic #16 (0.042): 0.022*"unit" + 0.013*"classifier" + 0.012*"pattern" + 0.008*"rbf" + 0.008*"letter" + 0.007*"word" + 0.006*"layer" + 0.006*"stage" + 0.006*"classification" + 0.006*"activation"
# 2018-03-10 21:53:28,612 : INFO : topic #1 (0.045): 0.059*"unit" + 0.019*"image" + 0.016*"layer" + 0.009*"pattern" + 0.008*"distance" + 0.007*"activation" + 0.007*"perturbation" + 0.006*"rule" + 0.006*"architecture" + 0.005*"symbol"
# 2018-03-10 21:53:28,613 : INFO : topic #12 (0.048): 0.028*"unit" + 0.011*"memory" + 0.010*"equation" + 0.008*"neuron" + 0.006*"gradient" + 0.006*"generalization" + 0.006*"activation" + 0.005*"backpropagation" + 0.005*"pattern" + 0.005*"rule"
# 2018-03-10 21:53:28,615 : INFO : topic diff=2.476902, rho=0.707107
# 2018-03-10 21:53:28,783 : INFO : PROGRESS: pass 0, at document #1500/7241
# 2018-03-10 21:53:30,447 : INFO : optimized alpha [0.041154325, 0.05623073, 0.039751947, 0.046035483, 0.047903586, 0.03152894, 0.04532726, 0.047625285, 0.052675616, 0.03256591, 0.0358579, 0.033438496, 0.06415798, 0.03593433, 0.04075952, 0.042636145, 0.051360752, 0.041583404, 0.042340074, 0.037470035, 0.04106559, 0.037191674, 0.037959866, 0.039946195, 0.03978897, 0.035901997, 0.040091157, 0.033263654, 0.038066477, 0.042544626]
# 2018-03-10 21:53:30,461 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 21:53:31,655 : INFO : topic #5 (0.032): 0.022*"block" + 0.015*"bit" + 0.015*"chip" + 0.011*"instruction" + 0.011*"mode" + 0.009*"signal" + 0.009*"layer" + 0.008*"analog" + 0.008*"operation" + 0.008*"channel"
# 2018-03-10 21:53:31,656 : INFO : topic #9 (0.033): 0.043*"rule" + 0.026*"transition" + 0.012*"saliency" + 0.011*"phase" + 0.010*"delay" + 0.009*"oscillation" + 0.008*"line" + 0.007*"phys" + 0.006*"synchronization" + 0.006*"dynamic"
# 2018-03-10 21:53:31,657 : INFO : topic #8 (0.053): 0.023*"motion" + 0.018*"field" + 0.014*"image" + 0.014*"direction" + 0.011*"unit" + 0.010*"layer" + 0.008*"velocity" + 0.007*"basis" + 0.006*"stimulus" + 0.006*"cell"
# 2018-03-10 21:53:31,659 : INFO : topic #1 (0.056): 0.063*"unit" + 0.020*"image" + 0.016*"layer" + 0.008*"distance" + 0.008*"pattern" + 0.007*"activation" + 0.006*"rule" + 0.005*"architecture" + 0.005*"perturbation" + 0.004*"backpropagation"
# 2018-03-10 21:53:31,659 : INFO : topic #12 (0.064): 0.022*"unit" + 0.012*"equation" + 0.011*"memory" + 0.009*"gradient" + 0.007*"loss" + 0.007*"generalization" + 0.006*"neuron" + 0.005*"descent" + 0.005*"recurrent" + 0.005*"rule"
# 2018-03-10 21:53:31,661 : INFO : topic diff=2.130825, rho=0.577350
# 2018-03-10 21:53:31,836 : INFO : PROGRESS: pass 0, at document #2000/7241
# 2018-03-10 21:53:33,424 : INFO : optimized alpha [0.049265902, 0.065751985, 0.049367722, 0.054880254, 0.05847342, 0.033425122, 0.057852883, 0.056777593, 0.06312271, 0.03651472, 0.04413238, 0.037159648, 0.08297609, 0.041116938, 0.045775924, 0.04845603, 0.062164627, 0.05160984, 0.047595657, 0.045495223, 0.04938573, 0.041149236, 0.041673277, 0.049104206, 0.044676363, 0.04331957, 0.049245242, 0.035407413, 0.043745168, 0.04793933]
# 2018-03-10 21:53:33,438 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 21:53:34,553 : INFO : topic #5 (0.033): 0.023*"block" + 0.023*"mode" + 0.020*"bit" + 0.015*"chip" + 0.013*"instruction" + 0.009*"propagation" + 0.008*"analog" + 0.008*"signal" + 0.008*"channel" + 0.007*"operation"
# 2018-03-10 21:53:34,555 : INFO : topic #27 (0.035): 0.030*"circuit" + 0.027*"packet" + 0.015*"neuron" + 0.013*"voltage" + 0.013*"expert" + 0.012*"stream" + 0.011*"dialogue" + 0.010*"analog" + 0.010*"synapse" + 0.010*"chip"
# 2018-03-10 21:53:34,556 : INFO : topic #8 (0.063): 0.025*"motion" + 0.019*"field" + 0.019*"image" + 0.018*"direction" + 0.010*"basis" + 0.009*"layer" + 0.009*"unit" + 0.008*"velocity" + 0.007*"stimulus" + 0.006*"edge"
# 2018-03-10 21:53:34,557 : INFO : topic #1 (0.066): 0.061*"unit" + 0.022*"image" + 0.016*"layer" + 0.008*"distance" + 0.006*"pattern" + 0.006*"activation" + 0.005*"rule" + 0.005*"architecture" + 0.004*"level" + 0.004*"perturbation"
# 2018-03-10 21:53:34,558 : INFO : topic #12 (0.083): 0.017*"unit" + 0.013*"equation" + 0.009*"memory" + 0.008*"gradient" + 0.008*"loss" + 0.007*"generalization" + 0.005*"rule" + 0.005*"recurrent" + 0.004*"constraint" + 0.004*"descent"
# 2018-03-10 21:53:34,559 : INFO : topic diff=1.904206, rho=0.500000
# 2018-03-10 21:53:34,766 : INFO : PROGRESS: pass 0, at document #2500/7241
# 2018-03-10 21:53:36,275 : INFO : optimized alpha [0.059055626, 0.07765562, 0.06106101, 0.06574911, 0.07011272, 0.03494088, 0.073866636, 0.0666219, 0.07279119, 0.03972682, 0.054203443, 0.04294087, 0.10810913, 0.04530232, 0.05233587, 0.05500368, 0.075323746, 0.06094, 0.051706113, 0.05494925, 0.059302863, 0.046294004, 0.044700835, 0.059124477, 0.049833264, 0.050499674, 0.062233187, 0.037824847, 0.049831077, 0.052610524]
# 2018-03-10 21:53:36,289 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 21:53:37,368 : INFO : topic #5 (0.035): 0.032*"block" + 0.021*"mode" + 0.020*"bit" + 0.017*"chip" + 0.013*"instruction" + 0.012*"propagation" + 0.008*"signal" + 0.007*"analog" + 0.007*"integrateandfire" + 0.007*"operation"
# 2018-03-10 21:53:37,369 : INFO : topic #27 (0.038): 0.046*"circuit" + 0.018*"packet" + 0.017*"expert" + 0.014*"bump" + 0.013*"chip" + 0.012*"voltage" + 0.012*"neuron" + 0.011*"stream" + 0.011*"analog" + 0.010*"synapse"
# 2018-03-10 21:53:37,370 : INFO : topic #16 (0.075): 0.039*"classifier" + 0.013*"classification" + 0.008*"letter" + 0.007*"constraint" + 0.007*"word" + 0.007*"optimization" + 0.007*"unit" + 0.006*"pattern" + 0.006*"program" + 0.006*"score"
# 2018-03-10 21:53:37,371 : INFO : topic #1 (0.078): 0.051*"unit" + 0.019*"image" + 0.013*"layer" + 0.008*"distance" + 0.006*"rating" + 0.006*"pattern" + 0.006*"perturbation" + 0.005*"activation" + 0.004*"prediction" + 0.004*"rule"
# 2018-03-10 21:53:37,373 : INFO : topic #12 (0.108): 0.013*"equation" + 0.012*"unit" + 0.010*"loss" + 0.009*"gradient" + 0.007*"memory" + 0.006*"constraint" + 0.006*"generalization" + 0.005*"similarity" + 0.004*"prediction" + 0.004*"update"
# 2018-03-10 21:53:37,374 : INFO : topic diff=1.844229, rho=0.447214
# 2018-03-10 21:53:37,584 : INFO : PROGRESS: pass 0, at document #3000/7241
# 2018-03-10 21:53:39,015 : INFO : optimized alpha [0.068681665, 0.09100865, 0.07610392, 0.07850984, 0.08514206, 0.03838382, 0.091699846, 0.07942355, 0.08581561, 0.044844043, 0.06625167, 0.050177515, 0.13892266, 0.050024476, 0.059975855, 0.061577573, 0.091357455, 0.070331305, 0.057914246, 0.066171445, 0.07094357, 0.051011667, 0.048520755, 0.07080432, 0.056599017, 0.059268445, 0.07776902, 0.0401562, 0.058726575, 0.057917573]
# 2018-03-10 21:53:39,030 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 21:53:40,071 : INFO : topic #5 (0.038): 0.042*"block" + 0.022*"bit" + 0.022*"chip" + 0.017*"mode" + 0.012*"propagation" + 0.010*"instruction" + 0.010*"integrateandfire" + 0.008*"conversion" + 0.008*"communication" + 0.008*"array"
# 2018-03-10 21:53:40,072 : INFO : topic #27 (0.040): 0.049*"circuit" + 0.020*"expert" + 0.016*"packet" + 0.015*"chip" + 0.013*"analog" + 0.012*"voltage" + 0.012*"bump" + 0.012*"stream" + 0.011*"synapse" + 0.011*"equilibrium"
# 2018-03-10 21:53:40,073 : INFO : topic #16 (0.091): 0.041*"classifier" + 0.014*"classification" + 0.009*"optimization" + 0.008*"constraint" + 0.008*"letter" + 0.008*"search" + 0.007*"score" + 0.007*"stage" + 0.007*"program" + 0.006*"word"
# 2018-03-10 21:53:40,074 : INFO : topic #6 (0.092): 0.021*"label" + 0.016*"support" + 0.016*"loss" + 0.016*"svm" + 0.014*"document" + 0.012*"bound" + 0.011*"risk" + 0.011*"classification" + 0.009*"optimization" + 0.008*"density"
# 2018-03-10 21:53:40,075 : INFO : topic #12 (0.139): 0.012*"equation" + 0.010*"gradient" + 0.009*"loss" + 0.009*"unit" + 0.007*"latent" + 0.006*"memory" + 0.006*"constraint" + 0.005*"prediction" + 0.005*"generalization" + 0.005*"similarity"
# 2018-03-10 21:53:40,077 : INFO : topic diff=1.706012, rho=0.408248
# 2018-03-10 21:53:40,308 : INFO : PROGRESS: pass 0, at document #3500/7241
# 2018-03-10 21:53:41,696 : INFO : optimized alpha [0.08153997, 0.10569395, 0.0938597, 0.09317011, 0.10138008, 0.0421399, 0.11541043, 0.09462609, 0.09912562, 0.049385067, 0.080990486, 0.057826847, 0.17449637, 0.056243896, 0.068333656, 0.06753091, 0.110295, 0.08246899, 0.06250045, 0.080106884, 0.08451263, 0.057053313, 0.052087564, 0.08518878, 0.064829506, 0.06949029, 0.097059496, 0.04266085, 0.0680411, 0.064093746]
# 2018-03-10 21:53:41,710 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 21:53:42,718 : INFO : topic #5 (0.042): 0.050*"block" + 0.024*"bit" + 0.022*"processor" + 0.016*"mode" + 0.016*"chip" + 0.010*"core" + 0.010*"memory" + 0.009*"communication" + 0.009*"propagation" + 0.008*"instruction"
# 2018-03-10 21:53:42,719 : INFO : topic #27 (0.043): 0.041*"circuit" + 0.026*"equilibrium" + 0.024*"expert" + 0.017*"gate" + 0.015*"bump" + 0.015*"mismatch" + 0.014*"chip" + 0.012*"stream" + 0.012*"analog" + 0.011*"packet"
# 2018-03-10 21:53:42,720 : INFO : topic #16 (0.110): 0.041*"classifier" + 0.014*"classification" + 0.011*"optimization" + 0.009*"score" + 0.009*"constraint" + 0.008*"search" + 0.008*"letter" + 0.007*"program" + 0.007*"tag" + 0.007*"instance"
# 2018-03-10 21:53:42,721 : INFO : topic #6 (0.115): 0.022*"label" + 0.020*"loss" + 0.015*"support" + 0.015*"document" + 0.013*"svm" + 0.013*"bound" + 0.013*"risk" + 0.012*"optimization" + 0.011*"classification" + 0.010*"regularization"
# 2018-03-10 21:53:42,722 : INFO : topic #12 (0.174): 0.010*"equation" + 0.010*"gradient" + 0.010*"latent" + 0.008*"loss" + 0.007*"sparsity" + 0.006*"unit" + 0.006*"prediction" + 0.006*"constraint" + 0.006*"update" + 0.006*"memory"
# 2018-03-10 21:53:42,724 : INFO : topic diff=1.592098, rho=0.377964
# 2018-03-10 21:53:42,988 : INFO : PROGRESS: pass 0, at document #4000/7241
# 2018-03-10 21:53:44,357 : INFO : optimized alpha [0.095012404, 0.12308142, 0.11513145, 0.11067182, 0.119576804, 0.046289876, 0.14468314, 0.111686856, 0.11399179, 0.05511304, 0.09934737, 0.066526376, 0.21831442, 0.06292447, 0.07778363, 0.07567284, 0.13216272, 0.09271285, 0.06802351, 0.09664157, 0.099895865, 0.06378062, 0.05489689, 0.10182931, 0.07277691, 0.083680764, 0.11962503, 0.04491901, 0.07974535, 0.07064004]
# 2018-03-10 21:53:44,371 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 21:53:45,355 : INFO : topic #27 (0.045): 0.040*"circuit" + 0.037*"equilibrium" + 0.023*"expert" + 0.018*"bump" + 0.015*"jump" + 0.015*"stream" + 0.014*"gate" + 0.012*"design" + 0.012*"chip" + 0.012*"mismatch"
# 2018-03-10 21:53:45,357 : INFO : topic #5 (0.046): 0.061*"block" + 0.022*"processor" + 0.019*"mode" + 0.019*"bit" + 0.013*"core" + 0.011*"instruction" + 0.011*"privacy" + 0.011*"chip" + 0.010*"memory" + 0.009*"implementation"
# 2018-03-10 21:53:45,358 : INFO : topic #16 (0.132): 0.040*"classifier" + 0.014*"classification" + 0.012*"optimization" + 0.011*"constraint" + 0.010*"score" + 0.010*"search" + 0.009*"program" + 0.008*"instance" + 0.007*"tag" + 0.006*"list"
# 2018-03-10 21:53:45,359 : INFO : topic #6 (0.145): 0.028*"loss" + 0.026*"label" + 0.016*"document" + 0.015*"optimization" + 0.014*"risk" + 0.014*"regularization" + 0.013*"support" + 0.012*"bound" + 0.012*"classification" + 0.011*"svm"
# 2018-03-10 21:53:45,360 : INFO : topic #12 (0.218): 0.014*"sparsity" + 0.012*"latent" + 0.011*"gradient" + 0.010*"equation" + 0.007*"loss" + 0.006*"prediction" + 0.006*"update" + 0.006*"constraint" + 0.005*"memory" + 0.005*"sparse"
# 2018-03-10 21:53:45,362 : INFO : topic diff=1.475693, rho=0.353553
# 2018-03-10 21:53:45,625 : INFO : PROGRESS: pass 0, at document #4500/7241
# 2018-03-10 21:53:46,942 : INFO : optimized alpha [0.11032299, 0.14146873, 0.1390808, 0.12891684, 0.13910574, 0.050995752, 0.17908046, 0.13137151, 0.1316128, 0.0613733, 0.12196691, 0.07692441, 0.267587, 0.071377486, 0.08846466, 0.0854254, 0.15951417, 0.10509139, 0.07415134, 0.11457, 0.11731963, 0.07093365, 0.059233014, 0.12096898, 0.081536315, 0.100158736, 0.14462347, 0.047670018, 0.09200083, 0.077376895]
# 2018-03-10 21:53:46,956 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 21:53:47,899 : INFO : topic #27 (0.048): 0.037*"circuit" + 0.034*"equilibrium" + 0.032*"expert" + 0.018*"jump" + 0.015*"stream" + 0.014*"bump" + 0.013*"mismatch" + 0.013*"design" + 0.011*"voltage" + 0.011*"device"
# 2018-03-10 21:53:47,900 : INFO : topic #5 (0.051): 0.060*"block" + 0.021*"bit" + 0.019*"processor" + 0.016*"mode" + 0.015*"core" + 0.014*"privacy" + 0.011*"communication" + 0.010*"memory" + 0.008*"buffet" + 0.008*"implementation"
# 2018-03-10 21:53:47,901 : INFO : topic #16 (0.160): 0.036*"classifier" + 0.014*"optimization" + 0.014*"classification" + 0.012*"search" + 0.010*"constraint" + 0.010*"score" + 0.010*"program" + 0.009*"instance" + 0.008*"accuracy" + 0.006*"stage"
# 2018-03-10 21:53:47,902 : INFO : topic #6 (0.179): 0.033*"loss" + 0.026*"label" + 0.016*"optimization" + 0.014*"risk" + 0.013*"regularization" + 0.013*"support" + 0.012*"document" + 0.011*"classification" + 0.011*"instance" + 0.011*"bound"
# 2018-03-10 21:53:47,904 : INFO : topic #12 (0.268): 0.015*"sparsity" + 0.014*"latent" + 0.012*"gradient" + 0.009*"equation" + 0.007*"loss" + 0.007*"sparse" + 0.007*"prediction" + 0.006*"update" + 0.006*"constraint" + 0.005*"descent"
# 2018-03-10 21:53:47,905 : INFO : topic diff=1.237037, rho=0.333333
# 2018-03-10 21:53:52,068 : INFO : -8.556 per-word bound, 376.3 perplexity estimate based on a held-out corpus of 500 documents with 412100 words
# 2018-03-10 21:53:52,068 : INFO : PROGRESS: pass 0, at document #5000/7241
# 2018-03-10 21:53:53,340 : INFO : optimized alpha [0.12398396, 0.16257179, 0.16636884, 0.14959306, 0.15747195, 0.05718731, 0.21804821, 0.15418044, 0.14717022, 0.06826605, 0.14945112, 0.087596714, 0.3233998, 0.080219634, 0.09826778, 0.093251094, 0.18965678, 0.12117646, 0.07821916, 0.13403511, 0.13690668, 0.0787027, 0.06341168, 0.14236839, 0.09193519, 0.12117429, 0.17237437, 0.051434603, 0.10557408, 0.08407476]
# 2018-03-10 21:53:53,355 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 21:53:54,255 : INFO : topic #27 (0.051): 0.033*"equilibrium" + 0.030*"expert" + 0.030*"circuit" + 0.017*"jump" + 0.017*"budget" + 0.017*"stream" + 0.014*"device" + 0.014*"design" + 0.011*"voltage" + 0.011*"bump"
# 2018-03-10 21:53:54,256 : INFO : topic #5 (0.057): 0.062*"block" + 0.029*"privacy" + 0.021*"communication" + 0.020*"bit" + 0.016*"processor" + 0.016*"core" + 0.013*"hash" + 0.012*"mode" + 0.011*"memory" + 0.010*"implementation"
# 2018-03-10 21:53:54,258 : INFO : topic #16 (0.190): 0.031*"classifier" + 0.016*"optimization" + 0.013*"classification" + 0.012*"search" + 0.011*"score" + 0.010*"constraint" + 0.010*"program" + 0.009*"accuracy" + 0.009*"instance" + 0.006*"query"
# 2018-03-10 21:53:54,259 : INFO : topic #6 (0.218): 0.037*"loss" + 0.025*"label" + 0.019*"optimization" + 0.014*"risk" + 0.013*"regularization" + 0.013*"document" + 0.012*"support" + 0.011*"classification" + 0.011*"bound" + 0.010*"instance"
# 2018-03-10 21:53:54,260 : INFO : topic #12 (0.323): 0.016*"latent" + 0.016*"sparsity" + 0.013*"gradient" + 0.009*"equation" + 0.007*"sparse" + 0.007*"update" + 0.006*"loss" + 0.006*"prediction" + 0.006*"item" + 0.006*"constraint"
# 2018-03-10 21:53:54,262 : INFO : topic diff=1.058667, rho=0.316228
# 2018-03-10 21:53:54,533 : INFO : PROGRESS: pass 0, at document #5500/7241
# 2018-03-10 21:53:55,757 : INFO : optimized alpha [0.13880336, 0.18169948, 0.19711304, 0.17213717, 0.1754821, 0.06488592, 0.26168764, 0.17959638, 0.16436401, 0.07593936, 0.18072641, 0.09994441, 0.3830391, 0.0893476, 0.110645294, 0.10037537, 0.22402292, 0.13853532, 0.08457206, 0.1535352, 0.15707873, 0.08695686, 0.06803086, 0.16498016, 0.10349489, 0.14379476, 0.20258981, 0.055384345, 0.11999885, 0.09208009]
# 2018-03-10 21:53:55,772 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 21:53:56,622 : INFO : topic #27 (0.055): 0.034*"equilibrium" + 0.029*"expert" + 0.024*"circuit" + 0.023*"stream" + 0.021*"budget" + 0.019*"jump" + 0.017*"design" + 0.011*"device" + 0.011*"mixability" + 0.011*"bump"
# 2018-03-10 21:53:56,623 : INFO : topic #5 (0.065): 0.073*"block" + 0.029*"privacy" + 0.025*"communication" + 0.022*"bit" + 0.021*"mode" + 0.016*"core" + 0.015*"hash" + 0.012*"processor" + 0.012*"memory" + 0.010*"implementation"
# 2018-03-10 21:53:56,624 : INFO : topic #16 (0.224): 0.028*"classifier" + 0.016*"optimization" + 0.014*"search" + 0.013*"classification" + 0.012*"score" + 0.010*"accuracy" + 0.010*"program" + 0.010*"constraint" + 0.010*"instance" + 0.007*"query"
# 2018-03-10 21:53:56,625 : INFO : topic #6 (0.262): 0.042*"loss" + 0.028*"label" + 0.018*"optimization" + 0.013*"risk" + 0.013*"document" + 0.012*"regularization" + 0.011*"support" + 0.011*"classification" + 0.011*"instance" + 0.010*"bound"
# 2018-03-10 21:53:56,626 : INFO : topic #12 (0.383): 0.018*"latent" + 0.015*"sparsity" + 0.012*"gradient" + 0.012*"tensor" + 0.008*"sparse" + 0.008*"equation" + 0.007*"update" + 0.006*"prediction" + 0.006*"loss" + 0.006*"descent"
# 2018-03-10 21:53:56,628 : INFO : topic diff=0.917141, rho=0.301511
# 2018-03-10 21:53:56,904 : INFO : PROGRESS: pass 0, at document #6000/7241
# 2018-03-10 21:53:58,127 : INFO : optimized alpha [0.15425615, 0.20541373, 0.22934735, 0.19488356, 0.19359657, 0.07257692, 0.31237292, 0.20573725, 0.18041871, 0.08446748, 0.21645188, 0.11194227, 0.45058, 0.098475546, 0.12273756, 0.108283676, 0.264141, 0.15482496, 0.09143798, 0.17221877, 0.17522383, 0.09682588, 0.072775364, 0.1913392, 0.11689195, 0.1708503, 0.23546755, 0.06040302, 0.13652833, 0.09933612]
# 2018-03-10 21:53:58,141 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 21:53:58,959 : INFO : topic #27 (0.060): 0.039*"equilibrium" + 0.030*"stream" + 0.030*"expert" + 0.024*"budget" + 0.020*"circuit" + 0.017*"design" + 0.015*"jump" + 0.012*"bump" + 0.011*"device" + 0.009*"implementation"
# 2018-03-10 21:53:58,960 : INFO : topic #5 (0.073): 0.076*"block" + 0.030*"privacy" + 0.028*"communication" + 0.020*"bit" + 0.018*"mode" + 0.018*"memory" + 0.018*"core" + 0.013*"hash" + 0.011*"implementation" + 0.010*"operation"
# 2018-03-10 21:53:58,961 : INFO : topic #16 (0.264): 0.023*"classifier" + 0.018*"optimization" + 0.015*"search" + 0.013*"score" + 0.011*"classification" + 0.010*"constraint" + 0.010*"accuracy" + 0.010*"instance" + 0.010*"program" + 0.009*"query"
# 2018-03-10 21:53:58,962 : INFO : topic #6 (0.312): 0.042*"loss" + 0.028*"label" + 0.021*"optimization" + 0.015*"risk" + 0.012*"regularization" + 0.012*"document" + 0.011*"support" + 0.011*"classification" + 0.010*"bound" + 0.010*"instance"
# 2018-03-10 21:53:58,963 : INFO : topic #12 (0.451): 0.017*"latent" + 0.014*"gradient" + 0.014*"tensor" + 0.014*"sparsity" + 0.009*"sparse" + 0.008*"update" + 0.007*"equation" + 0.007*"descent" + 0.007*"iteration" + 0.006*"prediction"
# 2018-03-10 21:53:58,965 : INFO : topic diff=0.825855, rho=0.288675
# 2018-03-10 21:53:59,247 : INFO : PROGRESS: pass 0, at document #6500/7241
# 2018-03-10 21:54:00,434 : INFO : optimized alpha [0.17023845, 0.23711687, 0.26125264, 0.21973085, 0.21498816, 0.081890605, 0.36480528, 0.2360683, 0.19882727, 0.09367477, 0.25388727, 0.12555502, 0.5177115, 0.109893814, 0.1359276, 0.11743089, 0.30874932, 0.16910726, 0.099334344, 0.18902221, 0.19629289, 0.10891134, 0.077737, 0.21723257, 0.13099077, 0.20072794, 0.2697646, 0.06641725, 0.15246655, 0.10831479]
# 2018-03-10 21:54:00,448 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 21:54:01,221 : INFO : topic #27 (0.066): 0.039*"equilibrium" + 0.032*"stream" + 0.028*"budget" + 0.027*"expert" + 0.020*"circuit" + 0.020*"design" + 0.014*"jump" + 0.010*"consumption" + 0.010*"gate" + 0.010*"bump"
# 2018-03-10 21:54:01,222 : INFO : topic #22 (0.078): 0.073*"neuron" + 0.038*"response" + 0.032*"cell" + 0.026*"population" + 0.017*"activity" + 0.016*"stimulus" + 0.013*"spike" + 0.010*"neuroscience" + 0.010*"mechanism" + 0.009*"noise"
# 2018-03-10 21:54:01,223 : INFO : topic #16 (0.309): 0.021*"classifier" + 0.020*"optimization" + 0.015*"search" + 0.014*"score" + 0.012*"query" + 0.011*"constraint" + 0.011*"program" + 0.010*"classification" + 0.010*"accuracy" + 0.010*"instance"
# 2018-03-10 21:54:01,224 : INFO : topic #6 (0.365): 0.049*"loss" + 0.026*"label" + 0.023*"optimization" + 0.015*"risk" + 0.011*"regularization" + 0.010*"setting" + 0.010*"bound" + 0.010*"support" + 0.010*"document" + 0.010*"classification"
# 2018-03-10 21:54:01,225 : INFO : topic #12 (0.518): 0.016*"tensor" + 0.016*"latent" + 0.015*"gradient" + 0.013*"sparsity" + 0.009*"sparse" + 0.008*"update" + 0.007*"iteration" + 0.007*"descent" + 0.006*"equation" + 0.006*"item"
# 2018-03-10 21:54:01,227 : INFO : topic diff=0.713115, rho=0.277350
# 2018-03-10 21:54:01,542 : INFO : PROGRESS: pass 0, at document #7000/7241
# 2018-03-10 21:54:02,748 : INFO : optimized alpha [0.18848902, 0.27311322, 0.2929838, 0.24885955, 0.23996471, 0.09240629, 0.4215997, 0.27003336, 0.22567478, 0.10403834, 0.29533917, 0.140899, 0.5906035, 0.12187776, 0.15375993, 0.12938052, 0.3578972, 0.18684156, 0.108035564, 0.20177464, 0.22076948, 0.12275319, 0.08386524, 0.244583, 0.1461771, 0.23582785, 0.30790737, 0.07471284, 0.17006761, 0.11808695]
# 2018-03-10 21:54:02,764 : INFO : merging changes from 500 documents into a model of 7241 documents
# 2018-03-10 21:54:03,510 : INFO : topic #27 (0.075): 0.039*"equilibrium" + 0.031*"stream" + 0.028*"expert" + 0.026*"budget" + 0.024*"design" + 0.017*"circuit" + 0.013*"jump" + 0.013*"aaron" + 0.012*"bid" + 0.010*"consumption"
# 2018-03-10 21:54:03,511 : INFO : topic #22 (0.084): 0.071*"neuron" + 0.039*"response" + 0.035*"cell" + 0.024*"population" + 0.019*"activity" + 0.015*"stimulus" + 0.014*"spike" + 0.011*"neuroscience" + 0.010*"fig" + 0.009*"mechanism"
# 2018-03-10 21:54:03,512 : INFO : topic #16 (0.358): 0.020*"classifier" + 0.020*"optimization" + 0.014*"search" + 0.014*"score" + 0.011*"query" + 0.011*"accuracy" + 0.011*"constraint" + 0.010*"program" + 0.009*"classification" + 0.009*"instance"
# 2018-03-10 21:54:03,513 : INFO : topic #6 (0.422): 0.057*"loss" + 0.024*"label" + 0.023*"optimization" + 0.017*"risk" + 0.011*"regularization" + 0.011*"setting" + 0.010*"support" + 0.010*"bound" + 0.010*"prediction" + 0.010*"minimization"
# 2018-03-10 21:54:03,514 : INFO : topic #12 (0.591): 0.018*"tensor" + 0.015*"gradient" + 0.015*"latent" + 0.012*"sparsity" + 0.009*"sparse" + 0.008*"iteration" + 0.007*"update" + 0.007*"descent" + 0.007*"equation" + 0.006*"prediction"
# 2018-03-10 21:54:03,516 : INFO : topic diff=0.616386, rho=0.267261
# 2018-03-10 21:54:05,941 : INFO : -8.362 per-word bound, 329.0 perplexity estimate based on a held-out corpus of 241 documents with 232076 words
# 2018-03-10 21:54:05,942 : INFO : PROGRESS: pass 0, at document #7241/7241
# 2018-03-10 21:54:06,511 : INFO : optimized alpha [0.20809755, 0.31412598, 0.32808214, 0.28104368, 0.2651628, 0.10235081, 0.47998405, 0.303611, 0.25209996, 0.11466999, 0.34257227, 0.15383187, 0.66372967, 0.13493063, 0.1718978, 0.13749209, 0.40927094, 0.20122398, 0.11632729, 0.21826133, 0.24209827, 0.13756342, 0.08937809, 0.27236763, 0.16254641, 0.27210855, 0.34938, 0.0835037, 0.18699157, 0.12783776]
# 2018-03-10 21:54:06,526 : INFO : merging changes from 241 documents into a model of 7241 documents
# 2018-03-10 21:54:07,235 : INFO : topic #27 (0.084): 0.063*"equilibrium" + 0.031*"design" + 0.026*"stream" + 0.026*"expert" + 0.025*"budget" + 0.015*"circuit" + 0.015*"aaron" + 0.012*"inception" + 0.011*"dai" + 0.010*"congestion"
# 2018-03-10 21:54:07,236 : INFO : topic #22 (0.089): 0.068*"neuron" + 0.041*"cell" + 0.038*"response" + 0.026*"population" + 0.018*"activity" + 0.013*"stimulus" + 0.012*"spike" + 0.011*"neuroscience" + 0.010*"fig" + 0.009*"dynamic"
# 2018-03-10 21:54:07,238 : INFO : topic #16 (0.409): 0.020*"classifier" + 0.019*"optimization" + 0.016*"query" + 0.014*"search" + 0.013*"score" + 0.010*"accuracy" + 0.010*"constraint" + 0.010*"instance" + 0.009*"classification" + 0.009*"program"
# 2018-03-10 21:54:07,239 : INFO : topic #6 (0.480): 0.058*"loss" + 0.027*"label" + 0.023*"optimization" + 0.016*"risk" + 0.011*"setting" + 0.011*"prediction" + 0.011*"divergence" + 0.010*"regularization" + 0.010*"bound" + 0.009*"log"
# 2018-03-10 21:54:07,240 : INFO : topic #12 (0.664): 0.016*"latent" + 0.015*"gradient" + 0.014*"tensor" + 0.011*"sparsity" + 0.008*"update" + 0.008*"sparse" + 0.007*"iteration" + 0.007*"descent" + 0.007*"preprint" + 0.006*"equation"
# 2018-03-10 21:54:07,242 : INFO : topic diff=0.496351, rho=0.258199
# 2018-03-10 21:54:07,246 : INFO : 'train_model'  60080.49 ms

# %%
lda.save(f'{PATH}/lda.gensim')
# Out:
# 2018-03-10 21:54:07,260 : INFO : saving LdaState object under /diskA/jethro/nips-papers/lda.gensim.state, separately None
# 2018-03-10 21:54:07,293 : INFO : saved /diskA/jethro/nips-papers/lda.gensim.state
# 2018-03-10 21:54:07,316 : INFO : saving LdaModel object under /diskA/jethro/nips-papers/lda.gensim, separately ['expElogbeta', 'sstats']
# 2018-03-10 21:54:07,317 : INFO : storing np array 'expElogbeta' to /diskA/jethro/nips-papers/lda.gensim.expElogbeta.npy
# 2018-03-10 21:54:07,325 : INFO : not storing attribute dispatcher
# 2018-03-10 21:54:07,325 : INFO : not storing attribute state
# 2018-03-10 21:54:07,326 : INFO : not storing attribute id2word
# 2018-03-10 21:54:07,328 : INFO : saved /diskA/jethro/nips-papers/lda.gensim

# %% [markdown]
# # Visualizing the Results

# %%
topics = lda.show_topics(formatted=False, num_words=6, num_topics=NUM_TOPICS)
d = dict()
for topic_id, words in topics:
    d[f'topic_{topic_id}'] = [word for rank, (word, prob) in enumerate(words)]

# %%
pd.DataFrame(d).transpose()
# Out:
#                     0              1               2            3  \
# topic_0        policy         action          reward        agent
# topic_1         layer   architecture            unit   activation
# topic_10        bound        theorem           proof          log
# topic_11      cluster     clustering          kmeans         gene
# topic_12       latent       gradient          tensor     sparsity
# topic_13      decoder           code           price       option
# topic_14        event       particle     measurement     recovery
# topic_15         face      detection       diffusion        frame
# topic_16   classifier   optimization           query       search
# topic_17    component          noise          source          pca
# topic_18       target      attention          memory          map
# topic_19        graph           node            edge         tree
# topic_2     inference            log      likelihood      mixture
# topic_20       kernel     regression       estimator   estimation
# topic_21         word       language            user     sentence
# topic_22       neuron           cell        response   population
# topic_23       convex           rank      projection   coordinate
# topic_24          arm        control      trajectory         cost
# topic_25     gradient           norm           arxiv   covariance
# topic_26         game         player             rnn       worker
# topic_27  equilibrium         design          stream       expert
# topic_28   constraint            map      relaxation        graph
# topic_29       bandit          brain             gan  interaction
# topic_3      datasets        dataset  classification     distance
# topic_4         image         region          object      dataset
# topic_5         block  communication         privacy          bit
# topic_6          loss          label    optimization         risk
# topic_7        oracle     embeddings      completion        noise
# topic_8        motion           cvpr            flow       filter
# topic_9          rule          group      transition     proposal
#
#                        4             5
# topic_0         decision        regret
# topic_1         preprint         mnist
# topic_10           lemma    complexity
# topic_11          center      distance
# topic_12          update        sparse
# topic_13     correlation         spike
# topic_14         episode        signal
# topic_15     recognition        person
# topic_16           score      accuracy
# topic_17          causal      subspace
# topic_18          module      location
# topic_19          vertex          path
# topic_2      observation        markov
# topic_20         density     selection
# topic_21             cnn      sequence
# topic_22        activity      stimulus
# topic_23  reconstruction      manifold
# topic_24        feedback      appendix
# topic_25     convergence      operator
# topic_26       multitask      strategy
# topic_27          budget       circuit
# topic_28            edge       segment
# topic_29            gans    prediction
# topic_3       similarity       ranking
# topic_4      recognition  segmentation
# topic_5           memory          hash
# topic_6          setting    prediction
# topic_7            arxiv   recognition
# topic_8            field         image
# topic_9         saliency         phase
