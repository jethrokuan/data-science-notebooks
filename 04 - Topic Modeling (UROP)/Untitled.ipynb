# %%
import sys
sys.path.insert(0, "..")

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
PATH="../data/ACM Data/"

# %%
from gensim.corpora import Dictionary

# %%
dct = Dictionary.load(f'{PATH}/dictionary.pkl')
# Out:
# 2018-03-09 02:54:08,924 : INFO : loading Dictionary object from ../data/ACM Data//dictionary.pkl
# 2018-03-09 02:54:08,933 : INFO : loaded ../data/ACM Data//dictionary.pkl

# %%
len(dct)
# Out:
# 19107

# %%
from gensim.corpora import MmCorpus

# %%
corpus = MmCorpus(f'{PATH}corpus.mm')
# Out:
# 2018-03-09 03:00:28,678 : INFO : initializing cython corpus reader from ../data/ACM Data/corpus.mm
# 2018-03-09 03:00:28,679 : INFO : accepted corpus with 2338 documents, 19107 features, 568518 non-zero entries

# %%
from gensim.models import LdaModel

# %%
model = LdaModel(corpus=corpus, id2word=dct, num_topics=35, chunksize=500, iterations=200, alpha='auto')
# Out:
# 2018-03-09 03:04:30,987 : INFO : using autotuned alpha, starting with [0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429, 0.028571429]
# 2018-03-09 03:04:30,989 : INFO : using symmetric eta at 0.02857142857142857
# 2018-03-09 03:04:30,992 : INFO : using serial LDA version on this node
# 2018-03-09 03:04:31,106 : INFO : running online (single-pass) LDA training, 35 topics, 1 passes over the supplied corpus of 2338 documents, updating model once every 500 documents, evaluating perplexity every 2338 documents, iterating 200x with a convergence threshold of 0.001000
# 2018-03-09 03:04:31,107 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2018-03-09 03:04:31,237 : INFO : PROGRESS: pass 0, at document #500/2338
# 2018-03-09 03:04:34,243 : INFO : optimized alpha [0.025733558, 0.03044975, 0.028379632, 0.026504423, 0.027254999, 0.028413709, 0.025949366, 0.024148799, 0.027556527, 0.024617413, 0.02926456, 0.025331989, 0.026677158, 0.026389219, 0.027813936, 0.027166095, 0.030355873, 0.026446536, 0.026508899, 0.026275927, 0.030193694, 0.025476957, 0.02911712, 0.029068768, 0.026895542, 0.024878895, 0.025580546, 0.031237502, 0.025202515, 0.030968839, 0.028081302, 0.02701625, 0.024152342, 0.02761413, 0.024360433]
# 2018-03-09 03:04:34,257 : INFO : merging changes from 500 documents into a model of 2338 documents
# 2018-03-09 03:04:34,402 : INFO : topic #32 (0.024): 0.033*"agent" + 0.023*"role" + 0.013*"action" + 0.013*"user" + 0.012*"structure" + 0.010*"organization" + 0.010*"reputation" + 0.009*"trust" + 0.009*"control" + 0.008*"interaction"
# 2018-03-09 03:04:34,403 : INFO : topic #7 (0.024): 0.021*"agent" + 0.014*"probability" + 0.012*"hypothesis" + 0.012*"entropy" + 0.011*"event" + 0.011*"trust" + 0.010*"distribution" + 0.009*"goal" + 0.009*"markov" + 0.009*"observation"
# 2018-03-09 03:04:34,404 : INFO : topic #1 (0.030): 0.030*"agent" + 0.014*"memory" + 0.013*"algorithm" + 0.012*"cost" + 0.012*"resource" + 0.008*"function" + 0.008*"image" + 0.007*"utility" + 0.007*"state" + 0.006*"rule"
# 2018-03-09 03:04:34,405 : INFO : topic #29 (0.031): 0.074*"agent" + 0.010*"interaction" + 0.010*"strategy" + 0.008*"group" + 0.008*"action" + 0.007*"commitment" + 0.006*"game" + 0.006*"function" + 0.006*"environment" + 0.005*"behavior"
# 2018-03-09 03:04:34,406 : INFO : topic #27 (0.031): 0.056*"agent" + 0.011*"state" + 0.011*"algorithm" + 0.008*"action" + 0.008*"step" + 0.008*"message" + 0.007*"constraint" + 0.007*"node" + 0.007*"network" + 0.007*"resource"
# 2018-03-09 03:04:34,408 : INFO : topic diff=26.613995, rho=1.000000
# 2018-03-09 03:04:34,484 : INFO : PROGRESS: pass 0, at document #1000/2338
# 2018-03-09 03:04:37,829 : INFO : optimized alpha [0.025621058, 0.036838289, 0.036861435, 0.028691858, 0.02835335, 0.030592557, 0.027345855, 0.025023017, 0.028538842, 0.028351916, 0.037726849, 0.032211185, 0.030730382, 0.02764678, 0.032649994, 0.027991509, 0.03796136, 0.028288206, 0.029286174, 0.029882705, 0.037161354, 0.028672701, 0.029261008, 0.03538987, 0.027526535, 0.026125349, 0.025865089, 0.035281163, 0.028649608, 0.034300271, 0.033882398, 0.030318402, 0.028045397, 0.028353145, 0.026169814]
# 2018-03-09 03:04:37,844 : INFO : merging changes from 500 documents into a model of 2338 documents
# 2018-03-09 03:04:37,966 : INFO : topic #7 (0.025): 0.020*"pattern" + 0.020*"event" + 0.017*"mining" + 0.014*"call" + 0.014*"rule" + 0.013*"distribution" + 0.012*"probability" + 0.012*"inference" + 0.012*"failure" + 0.011*"history"
# 2018-03-09 03:04:37,969 : INFO : topic #0 (0.026): 0.076*"state" + 0.034*"game" + 0.032*"player" + 0.020*"marker" + 0.013*"move" + 0.012*"action" + 0.012*"agent" + 0.010*"transition" + 0.008*"matrix" + 0.008*"payoff"
# 2018-03-09 03:04:37,971 : INFO : topic #20 (0.037): 0.011*"vehicle" + 0.010*"simulation" + 0.010*"message" + 0.009*"agent" + 0.008*"software" + 0.007*"communication" + 0.007*"network" + 0.006*"object" + 0.006*"cost" + 0.006*"document"
# 2018-03-09 03:04:37,973 : INFO : topic #10 (0.038): 0.015*"code" + 0.012*"software" + 0.011*"quality" + 0.009*"implementation" + 0.009*"graph" + 0.008*"student" + 0.008*"cache" + 0.007*"algorithm" + 0.007*"program" + 0.006*"performance"
# 2018-03-09 03:04:37,977 : INFO : topic #16 (0.038): 0.014*"task" + 0.014*"agent" + 0.012*"software" + 0.011*"program" + 0.011*"packet" + 0.010*"network" + 0.008*"architecture" + 0.007*"function" + 0.007*"team" + 0.007*"level"
# 2018-03-09 03:04:37,979 : INFO : topic diff=3.785520, rho=0.707107
# 2018-03-09 03:04:38,057 : INFO : PROGRESS: pass 0, at document #1500/2338
# 2018-03-09 03:04:40,588 : INFO : optimized alpha [0.027154211, 0.04687196, 0.043019842, 0.03202723, 0.029528249, 0.031243972, 0.029831754, 0.028890714, 0.029485513, 0.032936957, 0.048145585, 0.03694284, 0.034410693, 0.029657055, 0.039366476, 0.028584503, 0.049100719, 0.033049967, 0.032923236, 0.034127787, 0.04460768, 0.031206224, 0.029959116, 0.042031985, 0.028797777, 0.027747342, 0.029390913, 0.039629698, 0.032534186, 0.036988165, 0.037849911, 0.03406911, 0.034113325, 0.030675543, 0.028761776]
# 2018-03-09 03:04:40,597 : INFO : merging changes from 500 documents into a model of 2338 documents
# 2018-03-09 03:04:40,711 : INFO : topic #0 (0.027): 0.116*"state" + 0.040*"transition" + 0.033*"game" + 0.030*"gate" + 0.029*"player" + 0.013*"tag" + 0.011*"machine" + 0.011*"marker" + 0.008*"matrix" + 0.008*"algorithm"
# 2018-03-09 03:04:40,713 : INFO : topic #25 (0.028): 0.041*"frequency" + 0.026*"text" + 0.025*"document" + 0.020*"word" + 0.019*"change" + 0.019*"precision" + 0.019*"vector" + 0.009*"phrase" + 0.009*"source" + 0.009*"element"
# 2018-03-09 03:04:40,714 : INFO : topic #1 (0.047): 0.020*"memory" + 0.017*"transistor" + 0.013*"cache" + 0.011*"performance" + 0.010*"resource" + 0.010*"cost" + 0.010*"algorithm" + 0.009*"consumption" + 0.008*"architecture" + 0.007*"instruction"
# 2018-03-09 03:04:40,715 : INFO : topic #10 (0.048): 0.020*"code" + 0.012*"loop" + 0.012*"implementation" + 0.008*"software" + 0.008*"program" + 0.007*"performance" + 0.007*"graph" + 0.007*"block" + 0.007*"memory" + 0.007*"execution"
# 2018-03-09 03:04:40,717 : INFO : topic #16 (0.049): 0.017*"task" + 0.012*"architecture" + 0.010*"program" + 0.009*"clock" + 0.009*"software" + 0.008*"level" + 0.007*"hardware" + 0.007*"function" + 0.007*"instruction" + 0.007*"network"
# 2018-03-09 03:04:40,719 : INFO : topic diff=2.863457, rho=0.577350
# 2018-03-09 03:04:40,784 : INFO : PROGRESS: pass 0, at document #2000/2338
# 2018-03-09 03:04:42,613 : INFO : optimized alpha [0.028506506, 0.053541217, 0.050191931, 0.03489377, 0.031695958, 0.034065582, 0.030453924, 0.031756144, 0.032237254, 0.038095415, 0.051698893, 0.040423892, 0.036202926, 0.030742114, 0.04190607, 0.030070866, 0.055923849, 0.033738948, 0.038438827, 0.038711376, 0.050635707, 0.034038372, 0.034626424, 0.052186795, 0.032311887, 0.031629205, 0.030900296, 0.044345655, 0.035387781, 0.044964049, 0.045503285, 0.036152873, 0.042229854, 0.030987402, 0.031564668]
# 2018-03-09 03:04:42,628 : INFO : merging changes from 500 documents into a model of 2338 documents
# 2018-03-09 03:04:42,765 : INFO : topic #0 (0.029): 0.101*"state" + 0.066*"game" + 0.034*"player" + 0.033*"transition" + 0.019*"ee" + 0.016*"gate" + 0.014*"landmark" + 0.012*"tag" + 0.012*"marker" + 0.010*"machine"
# 2018-03-09 03:04:42,768 : INFO : topic #15 (0.030): 0.039*"service" + 0.028*"event" + 0.026*"state" + 0.021*"security" + 0.017*"property" + 0.015*"composition" + 0.010*"bpel" + 0.010*"protocol" + 0.009*"handler" + 0.009*"logic"
# 2018-03-09 03:04:42,769 : INFO : topic #23 (0.052): 0.028*"user" + 0.012*"screen" + 0.011*"display" + 0.010*"task" + 0.010*"network" + 0.010*"interface" + 0.008*"attribute" + 0.008*"input" + 0.007*"function" + 0.007*"wire"
# 2018-03-09 03:04:42,771 : INFO : topic #1 (0.054): 0.018*"memory" + 0.017*"resource" + 0.012*"performance" + 0.012*"cache" + 0.011*"consumption" + 0.011*"cost" + 0.010*"transistor" + 0.010*"algorithm" + 0.008*"address" + 0.007*"size"
# 2018-03-09 03:04:42,772 : INFO : topic #16 (0.056): 0.021*"task" + 0.012*"architecture" + 0.008*"network" + 0.008*"program" + 0.008*"packet" + 0.007*"software" + 0.007*"level" + 0.007*"clock" + 0.007*"function" + 0.006*"hardware"
# 2018-03-09 03:04:42,774 : INFO : topic diff=2.239329, rho=0.500000
# 2018-03-09 03:04:44,660 : INFO : -8.304 per-word bound, 316.1 perplexity estimate based on a held-out corpus of 338 documents with 304731 words
# 2018-03-09 03:04:44,661 : INFO : PROGRESS: pass 0, at document #2338/2338
# 2018-03-09 03:04:45,804 : INFO : optimized alpha [0.029358264, 0.064359069, 0.056603104, 0.037654005, 0.036618922, 0.038171403, 0.033086952, 0.037147701, 0.034441292, 0.044213545, 0.058034308, 0.045620356, 0.041366551, 0.032040473, 0.046378598, 0.032892473, 0.063734233, 0.036847968, 0.042120464, 0.042547051, 0.058305055, 0.038724557, 0.039281458, 0.061455105, 0.036390506, 0.037009768, 0.033045381, 0.053545441, 0.037261348, 0.049707178, 0.052846909, 0.041204233, 0.052186437, 0.032666415, 0.035629276]
# 2018-03-09 03:04:45,818 : INFO : merging changes from 338 documents into a model of 2338 documents
# 2018-03-09 03:04:45,944 : INFO : topic #0 (0.029): 0.090*"ee" + 0.088*"state" + 0.047*"game" + 0.045*"tag" + 0.032*"player" + 0.026*"transition" + 0.012*"dd" + 0.011*"gate" + 0.010*"landmark" + 0.009*"ink"
# 2018-03-09 03:04:45,946 : INFO : topic #13 (0.032): 0.020*"clause" + 0.019*"plot" + 0.017*"density" + 0.017*"delay" + 0.016*"ontology" + 0.015*"class" + 0.015*"assignment" + 0.012*"ci" + 0.012*"power" + 0.011*"distribution"
# 2018-03-09 03:04:45,947 : INFO : topic #23 (0.061): 0.028*"user" + 0.009*"screen" + 0.009*"network" + 0.009*"job" + 0.009*"attribute" + 0.009*"task" + 0.008*"interface" + 0.008*"display" + 0.006*"type" + 0.006*"function"
# 2018-03-09 03:04:45,949 : INFO : topic #16 (0.064): 0.016*"task" + 0.014*"packet" + 0.011*"architecture" + 0.009*"network" + 0.007*"router" + 0.007*"software" + 0.007*"hardware" + 0.006*"level" + 0.006*"trafc" + 0.006*"performance"
# 2018-03-09 03:04:45,950 : INFO : topic #1 (0.064): 0.032*"cache" + 0.019*"performance" + 0.017*"memory" + 0.014*"resource" + 0.013*"size" + 0.013*"cost" + 0.012*"algorithm" + 0.011*"server" + 0.008*"address" + 0.008*"access"
# 2018-03-09 03:04:45,952 : INFO : topic diff=1.560955, rho=0.447214

# %%
import pandas as pd

# %%
pd.DataFrame([[word for rank, (word, prob) in enumerate(words)]
              for topic_id, words in model.show_topics(formatted=False, num_words=6, num_topics=35)])
# Out:
#               0               1             2               3            4  \
# 0            ee           state          game             tag       player
# 1         cache     performance        memory        resource         size
# 2       student        material       concept         project    knowledge
# 3     predicate  representation     operation  transformation        probe
# 4         query        document          join       retrieval        index
# 5        client      reputation     warehouse         quality   repository
# 6            ed             eee         bound          buffer     property
# 7         event    distribution   probability      estimation         rate
# 8          rule          action          plan           story         goal
# 9      language            view     interface         surface         type
# 10         code  implementation       quality         service         loop
# 11         test        software          tool          course  engineering
# 12    algorithm            size         bound           proof        point
# 13       clause            plot       density           delay     ontology
# 14         core            test       voltage          scheme        fault
# 15     security           event       service        protocol        state
# 16         task          packet  architecture         network       router
# 17         node            path          edge         circuit        graph
# 18  participant            user         music         library         link
# 19        image           error        object           color        class
# 20         rate      simulation           ows     measurement  performance
# 21      cluster            file    similarity     maintenance  performance
# 22      service             web        device         content          xml
# 23         user          screen       network             job    attribute
# 24       sensor              tv      metadata           frame         user
# 25     document            text    collection            word         user
# 26       energy            line         point            area        trafc
# 27      network            node       service          packet     protocol
# 28        fault             bus          cost       usability   technology
# 29        video           group   interaction         gesture       people
# 30   technology        business       service       community          web
# 31          key          search     algorithm             bit          row
# 32         user          access          site         session      service
# 33         plan            view          join           stage     pipeline
# 34     database      prediction       pattern       attribute    operation
#
#               5
# 0    transition
# 1          cost
# 2        course
# 3          face
# 4          view
# 5      ontology
# 6     algorithm
# 7        stream
# 8         agent
# 9          code
# 10    execution
# 11         path
# 12     function
# 13        class
# 14     software
# 15       secure
# 16     software
# 17    algorithm
# 18    signature
# 19        pixel
# 20   throughput
# 21      dataset
# 22       server
# 23         task
# 24         slot
# 25       search
# 26       router
# 27      message
# 28        field
# 29         user
# 30  development
# 31         list
# 32       medium
# 33       output
# 34    predictor

# %%
corpus
